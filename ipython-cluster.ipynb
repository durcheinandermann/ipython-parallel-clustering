# %% [markdown]
# ##Clustering
# Clustering refers to a set of methods of unsupervised learning which aim to find groups in a data set. In general, these groups are desired to be homogenous in themselves but heterogeneous from each other. What exactly defines a homogeneous group with "similar" data points oftentimes depends on the domain of the application but in practise, the distance between features is often employed. [ref ISL p. 385].
# During clustering, every data point is assigned to one group. [Clustering can also be used to identify groups of similar features, ISL p. 386]
#
# #K-means
# K-means clustering is an iterative clustering technique and constitutes one of the most popular methods in clustering. It relies on a predetermined input k which denotes the number of clusters to be found. Various strategies for choosing k exist but are not subject of this discussion. K-means then finds K non-overlapping clusters and hard-assigns each data point to exactly one cluster.
# The criterion to measure the quality of a given clustering is the sum of squared distances between data points and corresponding centroids, which reflects the overall goal of finding homogeneous groups of similar points. The lower this criterion, the more homogeneous the clusters and the better the fit.
#
# The algorithm works in two steps and finds a local optimum of the before-mentioned criterion:
#     0. Pick k points as initial cluster centroids.
#     1. Assign data points to the nearest centroid (cluster). "Nearest" is frequently measured in terms of squared Euclidean distance between a data point and the centroids.
#     2. Update the cluster centroids by calculating a vector of means for all features across all data points in each cluster.
#
#     Steps 1 and 2 are repeated until convergence, that is until the assignments of data points no longer change or the cluster centers remain the same.
#
# #K-means/initializations
# A common strategy for initializing cluster centroids is random selection of points. This approach can be motivated by the fact that cluster centroids tend to be in "dense" areas where many points reside; thus choosing centers randomly will yield points close to true cluster with a higher probability. On the other hand, it may very well happen that two such randomly chosen points are very close to the same center - something we do not desire. Moreover, depending on this selection, the outcomes of K-means clustering may differ as the algorithm will find a local optimum starting from the initlization.
# Arthur and Vassilvitskii [XXX] have shown that a smarter initliazation strategy can improve this by achieving a lower value of the above mentioned optimization criterion - even frequently finding the optimal result on synthetic data - and also decrease the number of iterations [Arthur et al., p. 9]. Their approach is termed K-means++ and only chooses the first centroid at random. Sequentially, k-1 additional centers are chosen with a probability proportional to their squared distance from the previously selected centroids. This ensures diverse centroids and avoids choosing outliers. [Marco Capó et al., p. 930] One drawback of K-means++ is that its initialization needs k passes over the data, which consumes a lot of time on very big data sets. To overcome this problem, Bahmani et al. ["Scalable K-means"] developed a scalable version of k-means++ named k-means||.
#
#
# A simple serial implementation of K-means with an external initialization function that is capable of random or k-means++ style inititalization is shown in extract (??) 1 and 2.

# %% [markdown]
# Ipython parallel
#
# IPython parallel is a parallelization framework for IPython. It not only allows parallelization by harvesting the power of multiple CPUs or GPUs on the local machine but also allows for distributed computing across various machines which may reside at remote locations. The use of IPyhton Parallel requires the installation of the "ipyparallel" package.
#
# IPython parallel's architecture constis of a client, a controller and a set of engines. The controller consists of a hub and a scheduler. The hub keeps track of what's going on on the cluster, while the schedulers provide an asyncrhonous, in other words non-blocking during busy engines, interface between client and engines. Clients and engines connect to the controller.
# The engines listen for requests, run code and return the results.
#
# The work to be done requested by the client can be sent to different sets of engines through so-called "views". Various modes exist to manually control assimgent of work to specific engines or to allow for a load-balanced assigment determined by the scheduler. Moreover, users can state whether execution should be syncrhonous or asynchrononous, that is waiting or no waiting for results before continuing.
#
# Means of parallelization
#
# Common methods are the use of a parallel equivalent of Python's map function as well as executing functions remotely through ipyparallel's apply method. However, using IPyhton Parallel's "magic" commands like %px make it possible to execute single lines of code directly on the engines, which for example allows quick implementation of powerful list comprehension commands.
#
# Note that the engines have their own namespaces. Thus, to allow computations on engines, the engines must be equipped with the same functions / packages and have access to the necessary variables/data. The data can either be pushed to engines as a whole or partitioned by scattering it across engines. Using the latter approach, data can be re-gathered after computations on engines have finished.
#
# One drawback of a framework like IPython Parallel is the overhead cost of sending data back and forth (over the network) as well as the coordination of client, schedulers and engines. Thus, the question arises as to under which circumstances the benefits of parallel computation surpass the initial overhead costs. Section XXX aims to find these limits depending on the dataset size as well as on the number of clusters and engines.
#
# Below in extracts XYZ is an initialization of the IPython parallel framework used for computations in subsequent sections. XXX and YYY show parallel versions of the K-means and Gaussian Mixture Model implementations from section XXX.

# %%
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np

# %%
#from command line: ipcluster start -n 4

from ipyparallel import Client
#new client
rc = Client()
rc.purge_everything() #clean old rubbish

#create different views with different number of engines
e_0 = rc[0]
e_all = rc[:]
e_even = rc[::2]
e_odd = rc[1::2]
e_three = rc[1:4:1]

#import numpy and multivariate normal function on engines
for view in (e_0, e_all, e_even, e_odd, e_three):
    with view.sync_imports():
        import numpy
        from scipy.stats import multivariate_normal
    view.block = True
# Out:
# importing numpy on engine(s)
# importing multivariate_normal from scipy.stats on engine(s)
# importing numpy on engine(s)
# importing multivariate_normal from scipy.stats on engine(s)
# importing numpy on engine(s)
# importing multivariate_normal from scipy.stats on engine(s)
# importing numpy on engine(s)
# importing multivariate_normal from scipy.stats on engine(s)
# importing numpy on engine(s)
# importing multivariate_normal from scipy.stats on engine(s)

# %%
e_all.activate()
# %px print("ok")
# Out:
# [stdout:0] ok
# [stdout:1] ok

# %%
from sklearn.datasets.samples_generator import make_blobs

def create_data(size_list, k, features=2):
    res = []
    for number in size_list:
        np.random.seed(seed=None)
        a, b = make_blobs(n_samples=number, centers=k, n_features=features)
        res.append(a)
    return res

# %%
def init_centres(X, k, method):
    if method=="random":
        np.random.seed(seed=604)
        return X[np.random.choice(X.shape[0],k,replace=False),:]
    if method=="k++":
        #pick first point at random
        np.random.seed(seed=604)
        res = X[np.random.choice(X.shape[0],1,replace=False),:]
        #choose subsequent points
        if k>1:
            for j in range(1,k):
                #calculate distances
                Distances = np.array([min([np.linalg.norm(x-p)**2 \
                                        for p in res]) for x in X])
                #model distribution
                pdf = Distances/Distances.sum()
                cdf = pdf.cumsum()
                #choose point
                r = np.random.random()
                choice = np.where(cdf >= r)[0][0]
                #add to result array
                res = np.vstack((res, X[choice]))
            return res
        else:
            return res

# %%
def sk_means(X, k, seeding="random", ReturnPlot = True): #serial k-means
    if seeding=="random":
        c = init_centres(X, k, method="random")
    else:
        c = init_centres(X, k, method="k++")
    a = np.ndarray([len(X),1], )
    a = a.ravel()
    while True:
        #Assign points to clusters
        for q in range(0, len(a)):
            a[q] = np.argmin([np.linalg.norm(x - X[q]) for x in c])
        #Re-calculate cluster centres
        c_old = c.copy()
        for i in range(0,len(c)):
            c[i,0] = np.mean(X[a==i,0])
            c[i,1] = np.mean(X[a==i,1])
        if np.array_equal(c, c_old):
            if ReturnPlot == True:
                Fig1, ax = plt.subplots()
                for i in range(0,k):
                    ax.plot(X[a==i,0], X[a==i,1], '.')
                ax.plot(c[:,0], c[:,1], 'k^')
                return Fig1
            else:
                return a, c

# %%
def pk_means(X, k, view, seeding="random", ReturnPlot = True, ReturnParam = False):
    view.activate()
    if seeding=="random":
        c = init_centres(X, k, method="random")
    else:
        c = init_centres(X, k, method="k++")
    a = np.ndarray([len(X),1], )
    a = a.ravel()
    #partition a (array with cluster indices for each point) across engines
    view.scatter('b', a)
    #object b is non-writable for some reason
    # %px a = numpy.ndarray([len(b),1], )
    # %px a = a.ravel()
    # %px del b
    #partition X (array with points) across engines
    view.scatter('X', X) 
    while True:
        #Assign points to clusters
            #scatter data:
            #push c with cluster centres to all engines
            view['c'] = c
            #identify closest clusters for points remotely on partitioned data
            # %px for q in range(0, len(a)): a[q] = \
                numpy.argmin([numpy.linalg.norm(x - X[q]) for x in c])
            #gather data
            a = view.gather('a')#, block=True)

        #Re-calculate cluster centres
            c_old = c.copy()
            for i in range(0,len(c)):
                c[i,0] = np.mean(X[a==i,0])
                c[i,1] = np.mean(X[a==i,1])
            #check if cluster centers moved
            if np.array_equal(c, c_old):
                # %px del X, a, c
                if ReturnPlot == True:
                    Fig1, ax = plt.subplots()
                    for i in range(0,k):
                        ax.plot(X[a==i,0], X[a==i,1], '.')
                    ax.plot(c[:,0], c[:,1], 'k^')
                    return Fig1
                if ReturnParam == True: #to get parameters for GMM
                    #centroids, covariance matrices, shares of points in each cluster
                    return c, \
                        np.array([np.cov(X[a==i,], rowvar=False) for i in range(0,k)]), \
                        np.array([sum(a==i)/len(a) for i in range(0,k)])
                else:
                    return a, c

# %% [markdown]
# -> Mail in Lasse an Lasse

# %% [markdown]
# # Gaussian Mixture Model
#
# Mixture models overcome one of the weaknesses of K-means clustering. In K-means, every point is assigned to exactly one cluster. However, especially when dealing with outliers, which may in trugh not belong to any cluster at all, points in a cluster may become very, very different from each other and clusters are distorted. This is also due to the squared measure of Euclidean distance in K-means, which corresponds to searching for circular clusters where in reality the shapes may be significantly different from circles. [B 427]
#
# Instead of hard-assigning each point to exactly one cluster, mixture models do a soft-assignment, where data points are assigned to clusters along with a probability for the point to truly belong to the corresponding cluster. Gaussian mixture models assume a mixture of Gaussian distributions, each equipped with mean, covariance matrix. The individual Gaussians are linearly combined through mixing parameters assigned to each Gaussian that add up to 1.
#
# Initially, the assignment of points and the distribution parameters are unknown. A commonly employed solution for solving this problem is an iterative approach though the Expectation Maximization algorithm. Similarly to k-means, it consists of two main phases.
#
#     0. initialize parameters through (educated) guesses
#     1. Expectation phase: Soft-assign each point to each Gaussian by assigning each point a set of "responsibilities". These reflect the posterior probabilities that a point stems from the corresponding Gaussians given their current distribution parameters.
#     2. Maximization phase: update the parameters of each Gaussian through maximum likelihood estimates.
#
# The goodness of the fit is determined by the value of the log-likelihood function. Note that a problem arises if one of the points falls exactly onto one of the centroids; this will cause this point contribute an infinite term to the likelihood and the algorithm will diverge. A possible solution is to regularize the covariance matrices artificially.
#
# Repeat stepts 1 and 2 until convergence, that is once the parameters or the log-likelihood no longer change.  However, it may be useful to limit the number of iterations or set a threshold so that a result is accepted once the log-likelihood or the parameters only marginally change or convergence may take very long. [B 437]Like in the case of K-means, it is not guaranteed that the Expectation Maximization algorithm will find the global optimum. [B 438]
#
# #Initializations
# Similarly to K-means, one possibility of initializing the parameters of the Gaussians is to randomly assign points as centroids, use identity matrices for the covariance matrices and set the mixing proportions all equal.
#
# However, the Gaussian mixture model on average requires many more iterations than K-means to converge and every iteration is computationally much more expensive. Thus, it may make sense to first conduct a K-means clustering and use its result as an educated guess for initializing the Gaussians. While the obtained centroids are reused in this scenario, the covariance matrices can be initialized through the sample covariances of the K-means clusters and the mixing proportions may be set equal to the proportion of data points in the corresponding K-means cluster. [B 438]
#
# Like in the K-means case, various techniques exist to estimate the number of distributions, however this is beyond the scope of this discussion.

# %%
#packages for GMM function
from scipy.stats import multivariate_normal

# %%
def sGMM(X, k, threshold = 0, seeding = "random", ReturnPlots = True):
    #list of log likelihood
    likelihood = []
    ###
    #initialize parameters
    ###
    if seeding == "random":
        mixprop = np.ndarray([k,1],)
        mixprop = mixprop.ravel()
        mixprop[:] = 1/k

        mu = X[np.random.choice(X.shape[0],k,replace=False),:]

        #covariance matrix for sigma
        dimensions = np.shape(X)[1]
        sigma = [np.eye(dimensions)] * k

    if seeding == "kmeans++":
        mu, sigma, mixprop = pk_means(X, k, view, seeding="kmeans++", \
                                      ReturnPlot = False, ReturnParam = True)
        dimensions = np.shape(X)[1]
    if seeding == "kmeans":
        mu, sigma, mixprop = pk_means(X, k, view, seeding="random", \
                                      ReturnPlot = False, ReturnParam = True)
        dimensions = np.shape(X)[1]
    
    #responsibility array
    respon = np.zeros([len(X),k])
    
    #count iterations
    itero = 0
    while True:
        itero = itero + 1
        ###
        #Expectation
        ###
        #denominator for expectation calculation
        den = numpy.array([[mixprop[b]*multivariate_normal.pdf(row, \
                    mean= mu[b], cov=sigma[b]) for b in range(0,k)] \
                    for row in X]).sum(axis = 1)
        #calculate responsibility matrix
        respon = numpy.array([[mixprop[b]*multivariate_normal.pdf(row[1], \
                    mean= mu[b], cov=sigma[b]) / den[row[0]] for b in range(0,k)] \
                    for row in enumerate(X)])             
                
        ###
        #Maximization
        ###
        #remember old parameters
        mu_old = mu.copy()
        sigma_old = sigma.copy()
        mixprop_old = mixprop.copy()
        #calculate number of points in each component
        N_ks = np.sum(respon, axis = 0)
        for j in range(0,k):
            #means mu
            mu[j] = 1. / N_ks[j] * np.sum(respon[:, j] * X.T, axis = 1).T
            x_mu = np.matrix(X - mu[j])
            
            #sigma
            sigma[j] = np.array(1 / N_ks[j] * np.dot(np.multiply(x_mu.T, \
                                                        respon[:, j]), x_mu))
            
            #mixprop
            mixprop[j] = 1. / len(X) * N_ks[j]
        
        #record log likelihood
        likelihood.append(sum(np.log(den)))
        
        #check for convergence
        if threshold > 0 and itero > 1:
            if (likelihood[-1] - likelihood[-2]) < threshold:
                if ReturnPlots == True:
                    Fig0, ax = plt.subplots()
                    ax.plot(range(1,itero+1),likelihood)
                    if dimensions==2:
                        Fig1, ax = plt.subplots()
                        for j in range(0,k):
                            ax.scatter(X[np.argmax(respon, axis=1)==j,0], \
                                       X[np.argmax(respon, axis=1)==j,1], 
                                s=np.max(respon[np.argmax(respon, axis=1)==j], \
                                         axis=1)*10)
                        ax.plot(mu[:,0], mu[:,1], 'k^');
                    return Fig1, Fig0
                else:
                    return mu, sigma, mixprop, respon
        else:
            if np.array_equal(mu_old, mu) and np.array_equal(mixprop_old, mixprop) \
                                        and np.array_equal(sigma_old, sigma):
                if ReturnPlots == True:
                    Fig0, ax = plt.subplots()
                    ax.plot(range(1,itero+1),likelihood)
                    if dimensions==2:
                        Fig1, ax = plt.subplots()
                        for j in range(0,k):
                            ax.scatter(X[np.argmax(respon, axis=1)==j,0], \
                                       X[np.argmax(respon, axis=1)==j,1], \
                                s=np.max(respon[np.argmax(respon, axis=1)==j], \
                                        axis=1)*10)
                        ax.plot(mu[:,0], mu[:,1], 'k^');
                    return Fig1, Fig0
                else:
                    return mu, sigma, mixprop, respon

# %%
#len(XX[8])
#sGMM(X=XX[3], k=2)
# %time pGMM(X=XXX, k=2, view=e_all, threshold = 0.0001, seeding="kmeans++", ReturnPlots=True)
# %time sGMM(X=XXX, k=2, threshold = 0.0001, seeding="kmeans++", ReturnPlots=True)
# Out:
# Wall time: 3.49 s
# Wall time: 1.67 s
# (<matplotlib.figure.Figure at 0x18e661d0>,
#  <matplotlib.figure.Figure at 0x18e14c88>)

# %%
import numpy as np
#XXX = np.genfromtxt("\\\AURORA\\home\\CloudStation\\Uni\\Uni-Master\\Python\\twoclass.csv", delimiter=',', usecols=[0,1])
XXX = np.genfromtxt("C:\\home-aurora\\Uni\\Uni-Master\\Python\\twoclass.csv", delimiter=',', usecols=[0,1])

# %%
def pGMM(X, k, view, threshold = 0, seeding = "random", ReturnPlots = True):
    view.activate()
    #list of log likelihood
    likelihood = []
    ###
    #initialize parameters
    ###
    if seeding == "random":
        mixprop = np.ndarray([k,1],)
        mixprop = mixprop.ravel()
        mixprop[:] = 1/k

        mu = X[np.random.choice(X.shape[0],k,replace=False),:]

        #covariance matrix for sigma
        dimensions = np.shape(X)[1]
        sigma = [np.eye(dimensions)] * k

    if seeding == "kmeans++":
        mu, sigma, mixprop = pk_means(X, k, view, seeding="kmeans++", \
                                      ReturnPlot = False, ReturnParam = True)
        dimensions = np.shape(X)[1]
    if seeding == "kmeans":
        mu, sigma, mixprop = pk_means(X, k, view, seeding="random", \
                                      ReturnPlot = False, ReturnParam = True)
        dimensions = np.shape(X)[1]
    #responsibility array
    respon = np.zeros([len(X),k])    
    
    #scatter data points to engines
    view.scatter('X', X) 
    #push k to engines
    view['k'] = k
    
    #count iterations
    itero = 0
    while True:
        itero = itero + 1
        
        ##PARALLELIZATION: push things to engines
        #push (updated) parameters to engines
        view['mu'] = mu
        view['sigma'] = sigma
        view['mixprop'] = mixprop
        #responsibility array
        view.scatter('respon', respon)
        
        ###
        #Expectation
        ###
        
        #denominator for expectation calculation
        # %px den = numpy.array([[mixprop[b]*multivariate_normal.pdf(row, \
                        mean= mu[b], cov=sigma[b]) for b in range(0,k)] \
                        for row in X]).sum(axis = 1)
        #calculate responsibility matrix
        # %px respon = numpy.array([[mixprop[b]*multivariate_normal.pdf(row[1], \
                        mean= mu[b], cov=sigma[b]) / den[row[0]] for b in range(0,k)] \
                        for row in enumerate(X)])

        
        ##PARALLELIZATION: get things from engines
        respon = view.gather('respon')
        
        ###
        #Maximization
        ###
        #remember old parameters
        mu_old = mu.copy()
        sigma_old = sigma.copy()
        mixprop_old = mixprop.copy()
        #calculate number of points in each component
        N_ks = np.sum(respon, axis = 0)
        for j in range(0,k):
            #means mu
            mu[j] = 1. / N_ks[j] * np.sum(respon[:, j] * X.T, axis = 1).T
            x_mu = np.matrix(X - mu[j])
            
            #sigma
            sigma[j] = np.array(1 / N_ks[j] * np.dot(np.multiply(x_mu.T, \
                                                    respon[:, j]), x_mu))
            
            #mixprop
            mixprop[j] = 1. / len(X) * N_ks[j]
        
        #record log likelihood
        den = view.gather('den')
        likelihood.append(sum(np.log(den)))
        
        #check for convergence
        if threshold > 0 and itero > 1:
            if (likelihood[-1] - likelihood[-2]) < threshold:
                if ReturnPlots == True:
                    Fig0, ax = plt.subplots()
                    ax.plot(range(1,itero+1),likelihood)
                    ax.set_xlabel("iterations")
                    ax.set_ylabel("log likelihood")
                    if dimensions==2:
                        Fig1, ax = plt.subplots()
                        for j in range(0,k):
                            ax.scatter(X[np.argmax(respon, axis=1)==j,0], \
                                       X[np.argmax(respon, axis=1)==j,1], 
                                s=np.max(respon[np.argmax(respon, axis=1)==j],\
                                         axis=1)*10)
                        ax.plot(mu[:,0], mu[:,1], 'k^');
                    return Fig1, Fig0
                else:
                    return mu, sigma, mixprop, respon
        else:
            if np.array_equal(mu_old, mu) and np.array_equal(mixprop_old, mixprop)\
                                            and np.array_equal(sigma_old, sigma):
                if ReturnPlots == True:
                    Fig0, ax = plt.subplots()
                    ax.plot(range(1,itero+1),likelihood)
                    ax.set_xlabel("iterations")
                    ax.set_ylabel("log likelihood")
                    if dimensions==2:
                        Fig1, ax = plt.subplots()
                        for j in range(0,k):
                            ax.scatter(X[np.argmax(respon, axis=1)==j,0], \
                                       X[np.argmax(respon, axis=1)==j,1], 
                                s=np.max(respon[np.argmax(respon, axis=1)==j], \
                                         axis=1)*10)
                        ax.plot(mu[:,0], mu[:,1], 'k^');
                    return Fig1, Fig0
                else:
                    return mu, sigma, mixprop, respon

# %%
figg1, figg2 = pGMM(X=XXX, k=2, view=e_all, seeding = "random", ReturnPlots=True)
figg2.savefig("likelihood.eps", format="eps")
'figg1.savefig("points.eps", format="eps")

# %%
#########################################
#Speed experiment: K-means vs. K-means++#
#########################################
dataset_size = np.arange(5000,100000,30000)

rloops = 50
rk = 4

for u in range(1,rloops+1):
    XX = create_data(dataset_size, rk)
    lds = len(dataset_size)

    #RECORD TIMINGS
    ts0 = np.zeros([lds,3],)
    ts0[:,0]=dataset_size

    #serial k means
    for i in range(0,lds):
        print("s",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, view=e_all, ReturnPlot = False)
        ts0[i,1] = z.best

    #serial k means plus plus
    for i in range(0,lds):
        print("s++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, view=e_all, seeding="k++", ReturnPlot = False)
        ts0[i,2] = z.best
        
    if u == 1:
        tst0 = ts0
    else:
        tst0 = np.dstack((tst0,ts0))

#calculate mean values
ts0 = numpy.mean(tst, axis=2)


#plot
f_initspeeds, ax = plt.subplots()
ax.plot(ts0[:,0], ts0[:,1], 'r-', label="K-means")
ax.plot(ts0[:,0], ts0[:,2], 'r--', label="K-means++")

ax.set_title("Execution speeds of K-means and K-means++ Clustering")
ax.set_xlabel("data set size")
ax.set_ylabel("execution time (s)")
ax.legend();

f_initspeeds.savefig("initspeeds.eps", format="eps", bbox_inches="tight")
f_initspeeds.savefig("initspeeds.jpg", format="jpg", bbox_inches="tight")


###############################################################
#Speed experiment: K-means++, serial vs parallel, different ks#
###############################################################

from matplotlib.offsetbox import AnchoredText
dataset_size = np.arange(500,20000,1000)

#Average over many random datasets:
rloops = 100

#######
# k=2 #
#######
rk = 2

for u in range(1,rloops+1):
    XX = create_data(dataset_size, rk)
    lds = len(dataset_size)

    #RECORD TIMINGS
    ts2 = np.zeros([lds,3],)
    ts2[:,0]=dataset_size

    #serial k means plus plus
    for i in range(0,lds):
        print("s++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o sk_means(XX[i], rk, seeding="k++", ReturnPlot = False)
        ts2[i,1] = z.best

    #parallel k means plus plus
    for i in range(0,lds):
        print("p++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, e_all, seeding="k++", ReturnPlot = False)
        ts2[i,2] = z.best
        
    if u == 1:
        tst2 = ts2
    else:
        tst2 = np.dstack((tst2,ts2))

#calculate mean values
ts2 = numpy.mean(tst2, axis=2)

#######
# k=3 #
#######
rk = 3

for u in range(1,rloops+1):
    XX = create_data(dataset_size, rk)
    lds = len(dataset_size)

    #RECORD TIMINGS
    ts3 = np.zeros([lds,3],)
    ts3[:,0]=dataset_size

    #serial k means plus plus
    for i in range(0,lds):
        print("s++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o sk_means(XX[i], rk, seeding="k++", ReturnPlot = False)
        ts3[i,1] = z.best

    #parallel k means plus plus
    for i in range(0,lds):
        print("p++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, e_all, seeding="k++", ReturnPlot = False)
        ts3[i,2] = z.best
        
    if u == 1:
        tst3 = ts3
    else:
        tst3 = np.dstack((tst3,ts3))

#calculate mean values
ts3 = numpy.mean(tst3, axis=2)

#######
# k=4 #
#######
rk = 4

for u in range(1,rloops+1):
    XX = create_data(dataset_size, rk)
    lds = len(dataset_size)

    #RECORD TIMINGS
    ts4 = np.zeros([lds,3],)
    ts4[:,0]=dataset_size

    #serial k means plus plus
    for i in range(0,lds):
        print("s++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o sk_means(XX[i], rk, seeding="k++", ReturnPlot = False)
        ts4[i,1] = z.best

    #parallel k means plus plus
    for i in range(0,lds):
        print("p++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, e_all, seeding="k++", ReturnPlot = False)
        ts4[i,2] = z.best
        
    if u == 1:
        tst4 = ts4
    else:
        tst4 = np.dstack((tst4,ts4))

#calculate mean values
ts4 = numpy.mean(tst4, axis=2)

################
#     plot     #
################
f_skmeans_vs_pkmeans, (ax1, ax2, ax3) = plt.subplots(3, figsize=(8,11), sharex=True, sharey=True)

#ax1 for plot where k=2
ax1.plot(ts2[:,0], ts2[:,1], 'r--', label="Serial execution K-means++")
ax1.plot(ts2[:,0], ts2[:,2], 'b--', label="Parallel execution K-means++")

#ax2 for plot where k=3
ax2.plot(ts3[:,0], ts3[:,1], 'r--', label="Serial execution K-means++")
ax2.plot(ts3[:,0], ts3[:,2], 'b--', label="Parallel execution K-means++")

#ax3 for plot where k=4
ax3.plot(ts4[:,0], ts4[:,1], 'r--', label="Serial execution K-means++")
ax3.plot(ts4[:,0], ts4[:,2], 'b--', label="Parallel execution K-means++")

# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but bottom plot.
f_skmeans_vs_pkmeans.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f_skmeans_vs_pkmeans.axes[:-1]], visible=False)

#add labels etc.
ax3.set_xlabel("data set size")
ax2.set_ylabel("execution time (s)")

ax1.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)

ax1.add_artist(AnchoredText("k=2", loc=2))
ax2.add_artist(AnchoredText("k=3", loc=2))
ax3.add_artist(AnchoredText("k=4", loc=2))

f_skmeans_vs_pkmeans.savefig("f_skmeans_vs_pkmeans.eps", format="eps", bbox_inches="tight")
f_skmeans_vs_pkmeans.savefig("f_skmeans_vs_pkmeans.jpg", format="jpg", bbox_inches="tight")

#####################################################################
#Speed experiment: K-means++, serial vs parallel, different #engines#
#####################################################################

from matplotlib.offsetbox import AnchoredText
dataset_size = np.arange(500,20000,1000)

#Average over many random datasets:
rloops = 75

#######
# k=5 #
#######
rk = 5

for u in range(1,rloops+1):
    XX = create_data(dataset_size, rk)
    lds = len(dataset_size)

    #RECORD TIMINGS
    ts9 = np.zeros([lds,5],)
    ts9[:,0]=dataset_size

    #serial k means plus plus
    for i in range(0,lds):
        print("s++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o sk_means(XX[i], rk, seeding="k++", ReturnPlot = False)
        ts9[i,1] = z.best

    #parallel k means plus plus, all engines
    for i in range(0,lds):
        print("p++ four engines",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, e_even, seeding="k++", ReturnPlot = False)
        ts9[i,2] = z.best
    
    #parallel k means plus plus, three engines
    for i in range(0,lds):
        print("p++ three engines",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, e_three, seeding="k++", ReturnPlot = False)
        ts9[i,3] = z.best

    #parallel k means plus plus, two engines
    for i in range(0,lds):
        print("p++ two engines",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, e_all, seeding="k++", ReturnPlot = False)
        ts9[i,4] = z.best
        
    if u == 1:
        tst9 = ts9
    else:
        tst9 = np.dstack((tst9,ts9))

#calculate mean values
ts9 = numpy.mean(tst9, axis=2)


################
#     plot     #
################
feng, ax = plt.subplots(1, figsize=(8,5))

ax.plot(ts9[:,0], ts9[:,1], 'r--', label="Serial execution K-means++")
ax.plot(ts9[:,0], ts9[:,2], 'c--', label="Parallel execution K-means++ two engines")
ax.plot(ts9[:,0], ts9[:,3], linestyle='--', color='DarkSlateBlue', label="Parallel execution K-means++ three engines")
ax.plot(ts9[:,0], ts9[:,4], 'b--', label="Parallel execution K-means++ four engine")

ax.set_title("Execution speeds of K-means++ Clustering: Comparing engines")
ax.set_xlabel("data set size")
ax.set_ylabel("execution time (s)")
ax.legend();

feng.savefig("f_skmeans_vs_pkmeans_quad.jpg", format="jpg", bbox_inches="tight")
feng.savefig("f_skmeans_vs_pkmeans_quad.eps", format="eps", bbox_inches="tight")

#plt.savefig("f_skmeans_vs_pkmeans_dual.jpg", format="jpg", bbox_inches="tight")
#plt.savefig("f_skmeans_vs_pkmeans_dual.eps", format="eps", bbox_inches="tight")
# Out:
# s 1 5000
# 1 loop, best of 1: 3.15 s per loop
# s 1 35000
# 1 loop, best of 1: 9.19 s per loop
# s 1 65000
# 1 loop, best of 1: 4.53 s per loop
# s 1 95000
# 1 loop, best of 1: 13.3 s per loop
# s++ 1 5000
# 1 loop, best of 1: 1.76 s per loop
# s++ 1 35000
# 1 loop, best of 1: 5.24 s per loop
# s++ 1 65000
# 1 loop, best of 1: 5.66 s per loop
# s++ 1 95000
# 1 loop, best of 1: 15.4 s per loop
# s 2 5000
# 1 loop, best of 1: 2.52 s per loop
# s 2 35000
# 1 loop, best of 1: 21.3 s per loop
# s 2 65000
# 1 loop, best of 1: 14.3 s per loop
# s 2 95000
# 1 loop, best of 1: 58.7 s per loop
# s++ 2 5000
# 1 loop, best of 1: 2.23 s per loop
# s++ 2 35000
# 1 loop, best of 1: 3.12 s per loop
# s++ 2 65000
# 1 loop, best of 1: 27.7 s per loop
# s++ 2 95000
# 1 loop, best of 1: 26.1 s per loop
# s 3 5000
# 1 loop, best of 1: 6.91 s per loop
# s 3 35000
# 1 loop, best of 1: 3.3 s per loop
# s 3 65000
# 1 loop, best of 1: 4.56 s per loop
# s 3 95000
# 1 loop, best of 1: 4.7 s per loop
# s++ 3 5000
# 1 loop, best of 1: 793 ms per loop
# s++ 3 35000
# 1 loop, best of 1: 9.6 s per loop
# s++ 3 65000
# 1 loop, best of 1: 7.75 s per loop
# s++ 3 95000
# 1 loop, best of 1: 6.27 s per loop
# s 4 5000
# 1 loop, best of 1: 1.27 s per loop
# s 4 35000
# 1 loop, best of 1: 4.69 s per loop
# s 4 65000
# 1 loop, best of 1: 39.6 s per loop
# s 4 95000
# 1 loop, best of 1: 27.5 s per loop
# s++ 4 5000
# 1 loop, best of 1: 1.64 s per loop
# s++ 4 35000
# 1 loop, best of 1: 2.8 s per loop
# s++ 4 65000
# 1 loop, best of 1: 5.56 s per loop
# s++ 4 95000
# 1 loop, best of 1: 7.05 s per loop
# s 5 5000
# 1 loop, best of 1: 3.1 s per loop
# s 5 35000
# 1 loop, best of 1: 13.2 s per loop
# s 5 65000
# 1 loop, best of 1: 2.47 s per loop
# s 5 95000
# 1 loop, best of 1: 3.19 s per loop
# s++ 5 5000
# 1 loop, best of 1: 2.06 s per loop
# s++ 5 35000
# 1 loop, best of 1: 4.79 s per loop
# s++ 5 65000
# 1 loop, best of 1: 32 s per loop
# s++ 5 95000
# 1 loop, best of 1: 5.49 s per loop
# s 6 5000
# 1 loop, best of 1: 4.09 s per loop
# s 6 35000
# 1 loop, best of 1: 1.32 s per loop
# s 6 65000
# 1 loop, best of 1: 11.6 s per loop
# s 6 95000
# 1 loop, best of 1: 37.9 s per loop
# s++ 6 5000
# 1 loop, best of 1: 3.02 s per loop
# s++ 6 35000
# 1 loop, best of 1: 2.42 s per loop
# s++ 6 65000
# 1 loop, best of 1: 37.3 s per loop
# s++ 6 95000
# 1 loop, best of 1: 1min 30s per loop
# s 7 5000
# 1 loop, best of 1: 1.74 s per loop
# s 7 35000
# 1 loop, best of 1: 2.98 s per loop
# s 7 65000
# 1 loop, best of 1: 20.6 s per loop
# s 7 95000
# 1 loop, best of 1: 6.25 s per loop
# s++ 7 5000
# 1 loop, best of 1: 1.44 s per loop
# s++ 7 35000
# 1 loop, best of 1: 3.8 s per loop
# s++ 7 65000
# 1 loop, best of 1: 5.07 s per loop
# s++ 7 95000
# 1 loop, best of 1: 8.45 s per loop
# s 8 5000
# 1 loop, best of 1: 2.64 s per loop
# s 8 35000
# 1 loop, best of 1: 3.7 s per loop
# s 8 65000
# 1 loop, best of 1: 47 s per loop
# s 8 95000
# 1 loop, best of 1: 6.96 s per loop
# s++ 8 5000
# 1 loop, best of 1: 3.49 s per loop
# s++ 8 35000
# 1 loop, best of 1: 4.14 s per loop
# s++ 8 65000
# 1 loop, best of 1: 5.04 s per loop
# s++ 8 95000
# 1 loop, best of 1: 1min 17s per loop
# s 9 5000
# 1 loop, best of 1: 2.56 s per loop
# s 9 35000
# 1 loop, best of 1: 2.66 s per loop
# s 9 65000
# 1 loop, best of 1: 58.6 s per loop
# s 9 95000
# 1 loop, best of 1: 44 s per loop
# s++ 9 5000
# 1 loop, best of 1: 2.36 s per loop
# s++ 9 35000
# 1 loop, best of 1: 3.12 s per loop
# s++ 9 65000
# 1 loop, best of 1: 5.58 s per loop
# s++ 9 95000
# 1 loop, best of 1: 15.8 s per loop
# s 10 5000
# 1 loop, best of 1: 4.58 s per loop
# s 10 35000
# 1 loop, best of 1: 9.85 s per loop
# s 10 65000
# 1 loop, best of 1: 1min 2s per loop
# s 10 95000
# 1 loop, best of 1: 7.74 s per loop
# s++ 10 5000
# 1 loop, best of 1: 2.41 s per loop
# s++ 10 35000
# 1 loop, best of 1: 11.9 s per loop
# s++ 10 65000
# 1 loop, best of 1: 1min 23s per loop
# s++ 10 95000
# 1 loop, best of 1: 10.6 s per loop
# s 11 5000
# 1 loop, best of 1: 1.26 s per loop
# s 11 35000
# 1 loop, best of 1: 8.09 s per loop
# s 11 65000
# 1 loop, best of 1: 22.6 s per loop
# s 11 95000
# 1 loop, best of 1: 47.3 s per loop
# s++ 11 5000
# 1 loop, best of 1: 1.59 s per loop
# s++ 11 35000
# 1 loop, best of 1: 14.6 s per loop
# s++ 11 65000
# 1 loop, best of 1: 3.99 s per loop
# s++ 11 95000
# 1 loop, best of 1: 12.1 s per loop
# s 12 5000
# 1 loop, best of 1: 963 ms per loop
# s 12 35000
# 1 loop, best of 1: 4.76 s per loop
# s 12 65000
# 1 loop, best of 1: 6.34 s per loop
# s 12 95000
# 1 loop, best of 1: 16.4 s per loop
# s++ 12 5000
# 1 loop, best of 1: 1.1 s per loop
# s++ 12 35000
# 1 loop, best of 1: 4.49 s per loop
# s++ 12 65000
# 1 loop, best of 1: 9.55 s per loop
# s++ 12 95000
# 1 loop, best of 1: 15.2 s per loop
# s 13 5000
# 1 loop, best of 1: 966 ms per loop
# s 13 35000
# 1 loop, best of 1: 19.3 s per loop
# s 13 65000
# 1 loop, best of 1: 8.35 s per loop
# s 13 95000
# 1 loop, best of 1: 6.92 s per loop
# s++ 13 5000
# 1 loop, best of 1: 1.15 s per loop
# s++ 13 35000
# 1 loop, best of 1: 5.56 s per loop
# s++ 13 65000
# 1 loop, best of 1: 24.1 s per loop
# s++ 13 95000
# 1 loop, best of 1: 9.15 s per loop
# s 14 5000
# 1 loop, best of 1: 8.64 s per loop
# s 14 35000
# 1 loop, best of 1: 36.1 s per loop
# s 14 65000
# 1 loop, best of 1: 36.7 s per loop
# s 14 95000
# 1 loop, best of 1: 17.4 s per loop
# s++ 14 5000
# 1 loop, best of 1: 1.28 s per loop
# s++ 14 35000
# 1 loop, best of 1: 7.13 s per loop
# s++ 14 65000
# 1 loop, best of 1: 5.05 s per loop
# s++ 14 95000
# 1 loop, best of 1: 15 s per loop
# s 15 5000
# 1 loop, best of 1: 1.6 s per loop
# s 15 35000
# 1 loop, best of 1: 4.39 s per loop
# s 15 65000
# 1 loop, best of 1: 6.14 s per loop
# s 15 95000
# 1 loop, best of 1: 23.9 s per loop
# s++ 15 5000
# 1 loop, best of 1: 1.42 s per loop
# s++ 15 35000
# 1 loop, best of 1: 9.52 s per loop
# s++ 15 65000
# 1 loop, best of 1: 21.4 s per loop
# s++ 15 95000
# 1 loop, best of 1: 10.6 s per loop
# s 16 5000
# 1 loop, best of 1: 1.9 s per loop
# s 16 35000
# 1 loop, best of 1: 26.1 s per loop
# s 16 65000
# 1 loop, best of 1: 9.95 s per loop
# s 16 95000
# 1 loop, best of 1: 3.97 s per loop
# s++ 16 5000
# 1 loop, best of 1: 2.06 s per loop
# s++ 16 35000
# 1 loop, best of 1: 41.5 s per loop
# s++ 16 65000
# 1 loop, best of 1: 11.5 s per loop
# s++ 16 95000
# 1 loop, best of 1: 8.48 s per loop
# s 17 5000
# 1 loop, best of 1: 1.08 s per loop
# s 17 35000
# 1 loop, best of 1: 3.01 s per loop
# s 17 65000
# 1 loop, best of 1: 1.93 s per loop
# s 17 95000
# 1 loop, best of 1: 20.2 s per loop
# s++ 17 5000
# 1 loop, best of 1: 820 ms per loop
# s++ 17 35000
# 1 loop, best of 1: 4.84 s per loop
# s++ 17 65000
# 1 loop, best of 1: 48.3 s per loop
# s++ 17 95000
# 1 loop, best of 1: 59.5 s per loop
# s 18 5000
# 1 loop, best of 1: 1.24 s per loop
# s 18 35000
# 1 loop, best of 1: 3.36 s per loop
# s 18 65000
# 1 loop, best of 1: 3.05 s per loop
# s 18 95000
# 1 loop, best of 1: 12.2 s per loop
# s++ 18 5000
# 1 loop, best of 1: 1.27 s per loop
# s++ 18 35000
# 1 loop, best of 1: 3.77 s per loop
# s++ 18 65000
# 1 loop, best of 1: 6.12 s per loop
# s++ 18 95000
# 1 loop, best of 1: 14.3 s per loop
# s 19 5000
# 1 loop, best of 1: 2.37 s per loop
# s 19 35000
# 1 loop, best of 1: 5.95 s per loop
# s 19 65000
# 1 loop, best of 1: 3.53 s per loop
# s 19 95000
# 1 loop, best of 1: 2min 13s per loop
# s++ 19 5000
# 1 loop, best of 1: 1.11 s per loop
# s++ 19 35000
# 1 loop, best of 1: 5.12 s per loop
# s++ 19 65000
# 1 loop, best of 1: 14.3 s per loop
# s++ 19 95000
# 1 loop, best of 1: 1min 46s per loop
# s 20 5000
# 1 loop, best of 1: 2.56 s per loop
# s 20 35000
# 1 loop, best of 1: 23.4 s per loop
# s 20 65000
# 1 loop, best of 1: 1min 3s per loop
# s 20 95000
# 1 loop, best of 1: 3.99 s per loop
# s++ 20 5000
# 1 loop, best of 1: 2.55 s per loop
# s++ 20 35000
# 1 loop, best of 1: 5.86 s per loop
# s++ 20 65000
# 1 loop, best of 1: 3.94 s per loop
# s++ 20 95000
# 1 loop, best of 1: 5.6 s per loop
# s 21 5000
# 1 loop, best of 1: 6.44 s per loop
# s 21 35000
# 1 loop, best of 1: 3.34 s per loop
# s 21 65000
# 1 loop, best of 1: 2.97 s per loop
# s 21 95000
# 1 loop, best of 1: 1min 2s per loop
# s++ 21 5000
# 1 loop, best of 1: 4.87 s per loop
# s++ 21 35000
# 1 loop, best of 1: 3.46 s per loop
# s++ 21 65000
# 1 loop, best of 1: 4.02 s per loop
# s++ 21 95000
# 1 loop, best of 1: 6.24 s per loop
# s 22 5000
# 1 loop, best of 1: 4.29 s per loop
# s 22 35000
# 1 loop, best of 1: 13.2 s per loop
# s 22 65000
# 1 loop, best of 1: 11.6 s per loop
# s 22 95000
# 1 loop, best of 1: 46.1 s per loop
# s++ 22 5000
# 1 loop, best of 1: 962 ms per loop
# s++ 22 35000
# 1 loop, best of 1: 21.1 s per loop
# s++ 22 65000
# 1 loop, best of 1: 9.89 s per loop
# s++ 22 95000
# 1 loop, best of 1: 50.2 s per loop
# s 23 5000
# 1 loop, best of 1: 1.61 s per loop
# s 23 35000
# 1 loop, best of 1: 22 s per loop
# s 23 65000
# 1 loop, best of 1: 3.55 s per loop
# s 23 95000
# 1 loop, best of 1: 9.15 s per loop
# s++ 23 5000
# 1 loop, best of 1: 2.34 s per loop
# s++ 23 35000
# 1 loop, best of 1: 39.2 s per loop
# s++ 23 65000
# 1 loop, best of 1: 14.1 s per loop
# s++ 23 95000
# 1 loop, best of 1: 1min 3s per loop
# s 24 5000
# 1 loop, best of 1: 1.41 s per loop
# s 24 35000
# 1 loop, best of 1: 30.1 s per loop
# s 24 65000
# 1 loop, best of 1: 11.3 s per loop
# s 24 95000
# 1 loop, best of 1: 4 s per loop
# s++ 24 5000
# 1 loop, best of 1: 1.58 s per loop
# s++ 24 35000
# 1 loop, best of 1: 5.5 s per loop
# s++ 24 65000
# 1 loop, best of 1: 3.44 s per loop
# s++ 24 95000
# 1 loop, best of 1: 6.21 s per loop
# s 25 5000
# 1 loop, best of 1: 3.6 s per loop
# s 25 35000
# 1 loop, best of 1: 3.47 s per loop
# s 25 65000
# 1 loop, best of 1: 41.6 s per loop
# s 25 95000
# 1 loop, best of 1: 2min 36s per loop
# s++ 25 5000
# 1 loop, best of 1: 3.5 s per loop
# s++ 25 35000
# 1 loop, best of 1: 22.4 s per loop
# s++ 25 65000
# 1 loop, best of 1: 34.3 s per loop
# s++ 25 95000
# 1 loop, best of 1: 9.19 s per loop
# s 26 5000
# 1 loop, best of 1: 11.5 s per loop
# s 26 35000
# 1 loop, best of 1: 10.8 s per loop
# s 26 65000
# 1 loop, best of 1: 23.4 s per loop
# s 26 95000
# 1 loop, best of 1: 5.52 s per loop
# s++ 26 5000
# 1 loop, best of 1: 1.65 s per loop
# s++ 26 35000
# 1 loop, best of 1: 9.9 s per loop
# s++ 26 65000
# 1 loop, best of 1: 44.4 s per loop
# s++ 26 95000
# 1 loop, best of 1: 5.88 s per loop
# s 27 5000
# 1 loop, best of 1: 4.71 s per loop
# s 27 35000
# 1 loop, best of 1: 2.63 s per loop
# s 27 65000
# 1 loop, best of 1: 6.77 s per loop
# s 27 95000
# 1 loop, best of 1: 1min 21s per loop
# s++ 27 5000
# 1 loop, best of 1: 3.78 s per loop
# s++ 27 35000
# 1 loop, best of 1: 3.46 s per loop
# s++ 27 65000
# 1 loop, best of 1: 6.14 s per loop
# s++ 27 95000
# 1 loop, best of 1: 9.18 s per loop
# s 28 5000
# 1 loop, best of 1: 4.11 s per loop
# s 28 35000
# 1 loop, best of 1: 3.84 s per loop
# s 28 65000
# 1 loop, best of 1: 48.2 s per loop
# s 28 95000
# 1 loop, best of 1: 12 s per loop
# s++ 28 5000
# 1 loop, best of 1: 2.8 s per loop
# s++ 28 35000
# 1 loop, best of 1: 3.8 s per loop
# s++ 28 65000
# 1 loop, best of 1: 15.8 s per loop
# s++ 28 95000
# 1 loop, best of 1: 16.6 s per loop
# s 29 5000
# 1 loop, best of 1: 5.01 s per loop
# s 29 35000
# 1 loop, best of 1: 2.64 s per loop
# s 29 65000
# 1 loop, best of 1: 29.6 s per loop
# s 29 95000
# 1 loop, best of 1: 10.4 s per loop
# s++ 29 5000
# 1 loop, best of 1: 1.46 s per loop
# s++ 29 35000
# 1 loop, best of 1: 3.14 s per loop
# s++ 29 65000
# 1 loop, best of 1: 4.48 s per loop
# s++ 29 95000
# 1 loop, best of 1: 12.1 s per loop
# s 30 5000
# 1 loop, best of 1: 3.82 s per loop
# s 30 35000
# 1 loop, best of 1: 7.04 s per loop
# s 30 65000
# 1 loop, best of 1: 4.04 s per loop
# s 30 95000
# 1 loop, best of 1: 40.4 s per loop
# s++ 30 5000
# 1 loop, best of 1: 3.53 s per loop
# s++ 30 35000
# 1 loop, best of 1: 7.95 s per loop
# s++ 30 65000
# 1 loop, best of 1: 3.93 s per loop
# s++ 30 95000
# 1 loop, best of 1: 11.3 s per loop
# s 31 5000
# 1 loop, best of 1: 1.59 s per loop
# s 31 35000
# 1 loop, best of 1: 17.6 s per loop
# s 31 65000
# 1 loop, best of 1: 6.3 s per loop
# s 31 95000
# 1 loop, best of 1: 16.7 s per loop
# s++ 31 5000
# 1 loop, best of 1: 1.61 s per loop
# s++ 31 35000
# 1 loop, best of 1: 3.47 s per loop
# s++ 31 65000
# 1 loop, best of 1: 14.2 s per loop
# s++ 31 95000
# 1 loop, best of 1: 9.81 s per loop
# s 32 5000
# 1 loop, best of 1: 2.98 s per loop
# s 32 35000
# 1 loop, best of 1: 2.97 s per loop
# s 32 65000
# 1 loop, best of 1: 9.39 s per loop
# s 32 95000
# 1 loop, best of 1: 3.98 s per loop
# s++ 32 5000
# 1 loop, best of 1: 998 ms per loop
# s++ 32 35000
# 1 loop, best of 1: 3.45 s per loop
# s++ 32 65000
# 1 loop, best of 1: 12.1 s per loop
# s++ 32 95000
# 1 loop, best of 1: 6.24 s per loop
# s 33 5000
# 1 loop, best of 1: 1.39 s per loop
# s 33 35000
# 1 loop, best of 1: 2.66 s per loop
# s 33 65000
# 1 loop, best of 1: 43.5 s per loop
# s 33 95000
# 1 loop, best of 1: 30.1 s per loop
# s++ 33 5000
# 1 loop, best of 1: 1.09 s per loop
# s++ 33 35000
# 1 loop, best of 1: 4.8 s per loop
# s++ 33 65000
# 1 loop, best of 1: 3.94 s per loop
# s++ 33 95000
# 1 loop, best of 1: 6.33 s per loop
# s 34 5000
# 1 loop, best of 1: 5.68 s per loop
# s 34 35000
# 1 loop, best of 1: 3.65 s per loop
# s 34 65000
# 1 loop, best of 1: 16.9 s per loop
# s 34 95000
# 1 loop, best of 1: 29.3 s per loop
# s++ 34 5000
# 1 loop, best of 1: 989 ms per loop
# s++ 34 35000
# 1 loop, best of 1: 4.8 s per loop
# s++ 34 65000
# 1 loop, best of 1: 17.9 s per loop
# s++ 34 95000
# 1 loop, best of 1: 5.51 s per loop
# s 35 5000
# 1 loop, best of 1: 4.03 s per loop
# s 35 35000
# 1 loop, best of 1: 6.09 s per loop
# s 35 65000
# 1 loop, best of 1: 46.3 s per loop
# s 35 95000
# 1 loop, best of 1: 15.1 s per loop
# s++ 35 5000
# 1 loop, best of 1: 6 s per loop
# s++ 35 35000
# 1 loop, best of 1: 6.9 s per loop
# s++ 35 65000
# 1 loop, best of 1: 7.32 s per loop
# s++ 35 95000
# 1 loop, best of 1: 16.7 s per loop
# s 36 5000
# 1 loop, best of 1: 2.51 s per loop
# s 36 35000
# 1 loop, best of 1: 6.43 s per loop
# s 36 65000
# 1 loop, best of 1: 16.6 s per loop
# s 36 95000
# 1 loop, best of 1: 32.4 s per loop
# s++ 36 5000
# 1 loop, best of 1: 1.43 s per loop
# s++ 36 35000
# 1 loop, best of 1: 5.15 s per loop
# s++ 36 65000
# 1 loop, best of 1: 14.9 s per loop
# s++ 36 95000
# 1 loop, best of 1: 8.39 s per loop
# s 37 5000
# 1 loop, best of 1: 1.28 s per loop
# s 37 35000
# 1 loop, best of 1: 5.78 s per loop
# s 37 65000
# 1 loop, best of 1: 8.88 s per loop
# s 37 95000
# 1 loop, best of 1: 3.96 s per loop
# s++ 37 5000
# 1 loop, best of 1: 1.88 s per loop
# s++ 37 35000
# 1 loop, best of 1: 4.12 s per loop
# s++ 37 65000
# 1 loop, best of 1: 17 s per loop
# s++ 37 95000
# 1 loop, best of 1: 6.22 s per loop
# s 38 5000
# 1 loop, best of 1: 4.39 s per loop
# s 38 35000
# 1 loop, best of 1: 1.99 s per loop
# s 38 65000
# 1 loop, best of 1: 36.1 s per loop
# s 38 95000
# 1 loop, best of 1: 5.49 s per loop
# s++ 38 5000
# 1 loop, best of 1: 1.72 s per loop
# s++ 38 35000
# 1 loop, best of 1: 2.75 s per loop
# s++ 38 65000
# 1 loop, best of 1: 3.47 s per loop
# s++ 38 95000
# 1 loop, best of 1: 7.78 s per loop
# s 39 5000
# 1 loop, best of 1: 2.9 s per loop
# s 39 35000
# 1 loop, best of 1: 2.33 s per loop
# s 39 65000
# 1 loop, best of 1: 3.44 s per loop
# s 39 95000
# 1 loop, best of 1: 8.39 s per loop
# s++ 39 5000
# 1 loop, best of 1: 2.23 s per loop
# s++ 39 35000
# 1 loop, best of 1: 2.45 s per loop
# s++ 39 65000
# 1 loop, best of 1: 19.6 s per loop
# s++ 39 95000
# 1 loop, best of 1: 9.85 s per loop
# s 40 5000
# 1 loop, best of 1: 1.44 s per loop
# s 40 35000
# 1 loop, best of 1: 29.6 s per loop
# s 40 65000
# 1 loop, best of 1: 9.13 s per loop
# s 40 95000
# 1 loop, best of 1: 6.95 s per loop
# s++ 40 5000
# 1 loop, best of 1: 2.03 s per loop
# s++ 40 35000
# 1 loop, best of 1: 17.9 s per loop
# s++ 40 65000
# 1 loop, best of 1: 13.7 s per loop
# s++ 40 95000
# 1 loop, best of 1: 7.81 s per loop
# s 41 5000
# 1 loop, best of 1: 2.36 s per loop
# s 41 35000
# 1 loop, best of 1: 13.5 s per loop
# s 41 65000
# 1 loop, best of 1: 7.38 s per loop
# s 41 95000
# 1 loop, best of 1: 10.1 s per loop
# s++ 41 5000
# 1 loop, best of 1: 1.79 s per loop
# s++ 41 35000
# 1 loop, best of 1: 16.1 s per loop
# s++ 41 65000
# 1 loop, best of 1: 9.44 s per loop
# s++ 41 95000
# 1 loop, best of 1: 1min 19s per loop
# s 42 5000
# 1 loop, best of 1: 3.01 s per loop
# s 42 35000
# 1 loop, best of 1: 1.6 s per loop
# s 42 65000
# 1 loop, best of 1: 5.08 s per loop
# s 42 95000
# 1 loop, best of 1: 5.51 s per loop
# s++ 42 5000
# 1 loop, best of 1: 964 ms per loop
# s++ 42 35000
# 1 loop, best of 1: 2.11 s per loop
# s++ 42 65000
# 1 loop, best of 1: 6.69 s per loop
# s++ 42 95000
# 1 loop, best of 1: 44 s per loop
# s 43 5000
# 1 loop, best of 1: 2.99 s per loop
# s 43 35000
# 1 loop, best of 1: 2.97 s per loop
# s 43 65000
# 1 loop, best of 1: 13.8 s per loop
# s 43 95000
# 1 loop, best of 1: 12.9 s per loop
# s++ 43 5000
# 1 loop, best of 1: 4.02 s per loop
# s++ 43 35000
# 1 loop, best of 1: 4.17 s per loop
# s++ 43 65000
# 1 loop, best of 1: 3.97 s per loop
# s++ 43 95000
# 1 loop, best of 1: 18.1 s per loop
# s 44 5000
# 1 loop, best of 1: 2.18 s per loop
# s 44 35000
# 1 loop, best of 1: 3.01 s per loop
# s 44 65000
# 1 loop, best of 1: 5.75 s per loop
# s 44 95000
# 1 loop, best of 1: 6.24 s per loop
# s++ 44 5000
# 1 loop, best of 1: 971 ms per loop
# s++ 44 35000
# 1 loop, best of 1: 4.46 s per loop
# s++ 44 65000
# 1 loop, best of 1: 7.37 s per loop
# s++ 44 95000
# 1 loop, best of 1: 10 s per loop
# s 45 5000
# 1 loop, best of 1: 1.62 s per loop
# s 45 35000
# 1 loop, best of 1: 1.67 s per loop
# s 45 65000
# 1 loop, best of 1: 13.8 s per loop
# s 45 95000
# 1 loop, best of 1: 1min 10s per loop
# s++ 45 5000
# 1 loop, best of 1: 1.44 s per loop
# s++ 45 35000
# 1 loop, best of 1: 2.45 s per loop
# s++ 45 65000
# 1 loop, best of 1: 4.52 s per loop
# s++ 45 95000
# 1 loop, best of 1: 4.74 s per loop
# s 46 5000
# 1 loop, best of 1: 4.39 s per loop
# s 46 35000
# 1 loop, best of 1: 14 s per loop
# s 46 65000
# 1 loop, best of 1: 11 s per loop
# s 46 95000
# 1 loop, best of 1: 6.13 s per loop
# s++ 46 5000
# 1 loop, best of 1: 2.07 s per loop
# s++ 46 35000
# 1 loop, best of 1: 2.8 s per loop
# s++ 46 65000
# 1 loop, best of 1: 5.05 s per loop
# s++ 46 95000
# 1 loop, best of 1: 7.6 s per loop
# s 47 5000
# 1 loop, best of 1: 962 ms per loop
# s 47 35000
# 1 loop, best of 1: 1.3 s per loop
# s 47 65000
# 1 loop, best of 1: 4.09 s per loop
# s 47 95000
# 1 loop, best of 1: 6.28 s per loop
# s++ 47 5000
# 1 loop, best of 1: 1.3 s per loop
# s++ 47 35000
# 1 loop, best of 1: 2.44 s per loop
# s++ 47 65000
# 1 loop, best of 1: 4.5 s per loop
# s++ 47 95000
# 1 loop, best of 1: 5.58 s per loop
# s 48 5000
# 1 loop, best of 1: 2.33 s per loop
# s 48 35000
# 1 loop, best of 1: 5.32 s per loop
# s 48 65000
# 1 loop, best of 1: 8.31 s per loop
# s 48 95000
# 1 loop, best of 1: 29.8 s per loop
# s++ 48 5000
# 1 loop, best of 1: 6.68 s per loop
# s++ 48 35000
# 1 loop, best of 1: 7.5 s per loop
# s++ 48 65000
# 1 loop, best of 1: 18.2 s per loop
# s++ 48 95000
# 1 loop, best of 1: 7.86 s per loop
# s 49 5000
# 1 loop, best of 1: 1.24 s per loop
# s 49 35000
# 1 loop, best of 1: 11.5 s per loop
# s 49 65000
# 1 loop, best of 1: 26.9 s per loop
# s 49 95000
# 1 loop, best of 1: 1min 44s per loop
# s++ 49 5000
# 1 loop, best of 1: 1.13 s per loop
# s++ 49 35000
# 1 loop, best of 1: 14.7 s per loop
# s++ 49 65000
# 1 loop, best of 1: 10.7 s per loop
# s++ 49 95000
# 1 loop, best of 1: 10 s per loop
# s 50 5000
# 1 loop, best of 1: 1.28 s per loop
# s 50 35000
# 1 loop, best of 1: 8.8 s per loop
# s 50 65000
# 1 loop, best of 1: 1min 3s per loop
# s 50 95000
# 1 loop, best of 1: 4 s per loop
# s++ 50 5000
# 1 loop, best of 1: 1.12 s per loop
# s++ 50 35000
# 1 loop, best of 1: 9.86 s per loop
# s++ 50 65000
# 1 loop, best of 1: 54.7 s per loop
# s++ 50 95000
# 1 loop, best of 1: 9.16 s per loop
# s++ 1 500
# 1 loop, best of 1: 31.9 ms per loop
# s++ 1 1500
# 1 loop, best of 1: 57.5 ms per loop
# s++ 1 2500
# 1 loop, best of 1: 214 ms per loop
# s++ 1 3500
# 1 loop, best of 1: 133 ms per loop
# s++ 1 4500
# 1 loop, best of 1: 248 ms per loop
# s++ 1 5500
# 1 loop, best of 1: 387 ms per loop
# s++ 1 6500
# 1 loop, best of 1: 441 ms per loop
# s++ 1 7500
# 1 loop, best of 1: 392 ms per loop
# s++ 1 8500
# 1 loop, best of 1: 940 ms per loop
# s++ 1 9500
# 1 loop, best of 1: 357 ms per loop
# s++ 1 10500
# 1 loop, best of 1: 394 ms per loop
# s++ 1 11500
# 1 loop, best of 1: 595 ms per loop
# s++ 1 12500
# 1 loop, best of 1: 2.67 s per loop
# s++ 1 13500
# 1 loop, best of 1: 503 ms per loop
# s++ 1 14500
# 1 loop, best of 1: 962 ms per loop
# s++ 1 15500
# s++ 95 12500
# 1 loop, best of 1: 6.46 s per loop
# s++ 95 13500
# 1 loop, best of 1: 16.3 s per loop
# s++ 95 14500
# 1 loop, best of 1: 19.2 s per loop
# s++ 95 15500
# 1 loop, best of 1: 1.59 s per loop
# s++ 95 16500
# 1 loop, best of 1: 25.6 s per loop
# s++ 95 17500
# 1 loop, best of 1: 5.85 s per loop
# s++ 95 18500
# 1 loop, best of 1: 6.62 s per loop
# s++ 95 19500
# 1 loop, best of 1: 6.47 s per loop
# p++ 95 500
# 1 loop, best of 1: 1.27 s per loop
# p++ 95 1500
# 1 loop, best of 1: 1.47 s per loop
# p++ 95 2500
# 1 loop, best of 1: 1.95 s per loop
# p++ 95 3500
# 1 loop, best of 1: 3.13 s per loop
# p++ 95 4500
# 1 loop, best of 1: 1.43 s per loop
# p++ 95 5500
# 1 loop, best of 1: 970 ms per loop
# p++ 95 6500
# 1 loop, best of 1: 3.32 s per loop
# p++ 95 7500
# 1 loop, best of 1: 1.04 s per loop
# p++ 95 8500
# 1 loop, best of 1: 2.66 s per loop
# p++ 95 9500
# 1 loop, best of 1: 1.29 s per loop
# p++ 95 10500
# 1 loop, best of 1: 1.36 s per loop
# p++ 95 11500
# 1 loop, best of 1: 1.22 s per loop
# p++ 95 12500
# 1 loop, best of 1: 4.11 s per loop
# p++ 95 13500
# 1 loop, best of 1: 13.6 s per loop
# p++ 95 14500
# 1 loop, best of 1: 12.7 s per loop
# p++ 95 15500
# 1 loop, best of 1: 1.47 s per loop
# p++ 95 16500
# 1 loop, best of 1: 5.61 s per loop
# p++ 95 17500
# 1 loop, best of 1: 4.51 s per loop
# p++ 95 18500
# 1 loop, best of 1: 5.26 s per loop
# p++ 95 19500
# 1 loop, best of 1: 3.09 s per loop
# s++ 96 500
# 1 loop, best of 1: 239 ms per loop
# s++ 96 1500
# 1 loop, best of 1: 356 ms per loop
# s++ 96 2500
# 1 loop, best of 1: 396 ms per loop
# s++ 96 3500
# 1 loop, best of 1: 949 ms per loop
# s++ 96 4500
# 1 loop, best of 1: 1.42 s per loop
# s++ 96 5500
# 1 loop, best of 1: 975 ms per loop
# s++ 96 6500
# 1 loop, best of 1: 3.73 s per loop
# s++ 96 7500
# 1 loop, best of 1: 1.47 s per loop
# s++ 96 8500
# 1 loop, best of 1: 1.88 s per loop
# s++ 96 9500
# 1 loop, best of 1: 3.01 s per loop
# s++ 96 10500
# 1 loop, best of 1: 3.81 s per loop
# s++ 96 11500
# 1 loop, best of 1: 1.19 s per loop
# s++ 96 12500
# 1 loop, best of 1: 1.57 s per loop
# s++ 96 13500
# 1 loop, best of 1: 1.72 s per loop
# s++ 96 14500
# 1 loop, best of 1: 1.85 s per loop
# s++ 96 15500
# 1 loop, best of 1: 4.53 s per loop
# s++ 96 16500
# 1 loop, best of 1: 4.02 s per loop
# s++ 96 17500
# 1 loop, best of 1: 13.7 s per loop
# s++ 96 18500
# 1 loop, best of 1: 3.65 s per loop
# s++ 96 19500
# 1 loop, best of 1: 17.1 s per loop
# p++ 96 500
# 1 loop, best of 1: 1.62 s per loop
# p++ 96 1500
# 1 loop, best of 1: 1.9 s per loop
# p++ 96 2500
# 1 loop, best of 1: 965 ms per loop
# p++ 96 3500
# 1 loop, best of 1: 1.77 s per loop
# p++ 96 4500
# 1 loop, best of 1: 1.68 s per loop
# p++ 96 5500
# 1 loop, best of 1: 1.12 s per loop
# p++ 96 6500
# 1 loop, best of 1: 2.87 s per loop
# p++ 96 7500
# 1 loop, best of 1: 1.56 s per loop
# p++ 96 8500
# 1 loop, best of 1: 2.68 s per loop
# p++ 96 9500
# 1 loop, best of 1: 1.48 s per loop
# p++ 96 10500
# 1 loop, best of 1: 1.54 s per loop
# p++ 96 11500
# 1 loop, best of 1: 1.42 s per loop
# p++ 96 12500
# 1 loop, best of 1: 1.51 s per loop
# p++ 96 13500
# 1 loop, best of 1: 1.36 s per loop
# p++ 96 14500
# 1 loop, best of 1: 1.61 s per loop
# p++ 96 15500
# 1 loop, best of 1: 3.15 s per loop
# p++ 96 16500
# 1 loop, best of 1: 3.03 s per loop
# p++ 96 17500
# 1 loop, best of 1: 18.7 s per loop
# p++ 96 18500
# 1 loop, best of 1: 9.88 s per loop
# p++ 96 19500
# 1 loop, best of 1: 3.53 s per loop
# s++ 97 500
# 1 loop, best of 1: 48 ms per loop
# s++ 97 1500
# 1 loop, best of 1: 174 ms per loop
# s++ 97 2500
# 1 loop, best of 1: 211 ms per loop
# s++ 97 3500
# 1 loop, best of 1: 1.21 s per loop
# s++ 97 4500
# 1 loop, best of 1: 693 ms per loop
# s++ 97 5500
# 1 loop, best of 1: 1.59 s per loop
# s++ 97 6500
# 1 loop, best of 1: 529 ms per loop
# s++ 97 7500
# 1 loop, best of 1: 1.13 s per loop
# s++ 97 8500
# 1 loop, best of 1: 3.64 s per loop
# s++ 97 9500
# 1 loop, best of 1: 983 ms per loop
# s++ 97 10500
# 1 loop, best of 1: 2.56 s per loop
# s++ 97 11500
# 1 loop, best of 1: 2.01 s per loop
# s++ 97 12500
# 1 loop, best of 1: 997 ms per loop
# s++ 97 13500
# 1 loop, best of 1: 2.64 s per loop
# s++ 97 14500
# 1 loop, best of 1: 1.5 s per loop
# s++ 97 15500
# 1 loop, best of 1: 4.81 s per loop
# s++ 97 16500
# 1 loop, best of 1: 6.32 s per loop
# s++ 97 17500
# 1 loop, best of 1: 3.04 s per loop
# s++ 97 18500
# 1 loop, best of 1: 39 s per loop
# s++ 97 19500
# 1 loop, best of 1: 2.01 s per loop
# p++ 97 500
# 1 loop, best of 1: 1.71 s per loop
# p++ 97 1500
# 1 loop, best of 1: 1.36 s per loop
# p++ 97 2500
# 1 loop, best of 1: 806 ms per loop
# p++ 97 3500
# 1 loop, best of 1: 2.65 s per loop
# p++ 97 4500
# 1 loop, best of 1: 1.38 s per loop
# p++ 97 5500
# 1 loop, best of 1: 2.89 s per loop
# p++ 97 6500
# 1 loop, best of 1: 870 ms per loop
# p++ 97 7500
# 1 loop, best of 1: 1.39 s per loop
# p++ 97 8500
# 1 loop, best of 1: 1.07 s per loop
# p++ 97 9500
# 1 loop, best of 1: 1.33 s per loop
# p++ 97 10500
# 1 loop, best of 1: 6.94 s per loop
# p++ 97 11500
# 1 loop, best of 1: 1.4 s per loop
# p++ 97 12500
# 1 loop, best of 1: 1.12 s per loop
# p++ 97 13500
# 1 loop, best of 1: 2.35 s per loop
# p++ 97 14500
# 1 loop, best of 1: 1.22 s per loop
# p++ 97 15500
# 1 loop, best of 1: 3.19 s per loop
# p++ 97 16500
# 1 loop, best of 1: 3.58 s per loop
# p++ 97 17500
# 1 loop, best of 1: 2.45 s per loop
# p++ 97 18500
# 1 loop, best of 1: 23.2 s per loop
# p++ 97 19500
# 1 loop, best of 1: 1.91 s per loop
# s++ 98 500
# 1 loop, best of 1: 70.2 ms per loop
# s++ 98 1500
# 1 loop, best of 1: 165 ms per loop
# s++ 98 2500
# 1 loop, best of 1: 270 ms per loop
# s++ 98 3500
# 1 loop, best of 1: 1.78 s per loop
# s++ 98 4500
# 1 loop, best of 1: 582 ms per loop
# s++ 98 5500
# 1 loop, best of 1: 703 ms per loop
# s++ 98 6500
# 1 loop, best of 1: 1.14 s per loop
# s++ 98 7500
# 1 loop, best of 1: 2.19 s per loop
# s++ 98 8500
# 1 loop, best of 1: 1.28 s per loop
# s++ 98 9500
# 1 loop, best of 1: 987 ms per loop
# s++ 98 10500
# 1 loop, best of 1: 3.06 s per loop
# s++ 98 11500
# 1 loop, best of 1: 4.14 s per loop
# s++ 98 12500
# 1 loop, best of 1: 1.88 s per loop
# s++ 98 13500
# 1 loop, best of 1: 3.94 s per loop
# s++ 98 14500
# 1 loop, best of 1: 2.54 s per loop
# s++ 98 15500
# 1 loop, best of 1: 7.37 s per loop
# s++ 98 16500
# 1 loop, best of 1: 3.24 s per loop
# s++ 98 17500
# 1 loop, best of 1: 3.45 s per loop
# s++ 98 18500
# 1 loop, best of 1: 2.33 s per loop
# s++ 98 19500
# 1 loop, best of 1: 2.93 s per loop
# p++ 98 500
# 1 loop, best of 1: 885 ms per loop
# p++ 98 1500
# 1 loop, best of 1: 1.06 s per loop
# p++ 98 2500
# 1 loop, best of 1: 695 ms per loop
# p++ 98 3500
# 1 loop, best of 1: 1.48 s per loop
# p++ 98 4500
# 1 loop, best of 1: 1.39 s per loop
# p++ 98 5500
# 1 loop, best of 1: 948 ms per loop
# p++ 98 6500
# 1 loop, best of 1: 2.16 s per loop
# p++ 98 7500
# 1 loop, best of 1: 6.7 s per loop
# p++ 98 8500
# 1 loop, best of 1: 6.41 s per loop
# p++ 98 9500
# 1 loop, best of 1: 1.13 s per loop
# p++ 98 10500
# 1 loop, best of 1: 2.71 s per loop
# p++ 98 11500
# 1 loop, best of 1: 4.36 s per loop
# p++ 98 12500
# 1 loop, best of 1: 1.71 s per loop
# p++ 98 13500
# 1 loop, best of 1: 1.59 s per loop
# p++ 98 14500
# 1 loop, best of 1: 1.64 s per loop
# p++ 98 15500
# 1 loop, best of 1: 6.92 s per loop
# p++ 98 16500
# 1 loop, best of 1: 2.41 s per loop
# 1 loop, best of 1: 2.5 s per loop
# s++ 100 6500
# 1 loop, best of 1: 1.9 s per loop
# s++ 100 7500
# 1 loop, best of 1: 1.65 s per loop
# s++ 100 8500
# 1 loop, best of 1: 880 ms per loop
# s++ 100 9500
# 1 loop, best of 1: 1.43 s per loop
# s++ 100 10500
# 1 loop, best of 1: 2.07 s per loop
# s++ 100 11500
# 1 loop, best of 1: 1.45 s per loop
# s++ 100 12500
# 1 loop, best of 1: 5.92 s per loop
# s++ 100 13500
# 1 loop, best of 1: 1.4 s per loop
# s++ 100 14500
# 1 loop, best of 1: 6.57 s per loop
# s++ 100 15500
# 1 loop, best of 1: 2.31 s per loop
# s++ 100 16500
# 1 loop, best of 1: 2.85 s per loop
# s++ 100 17500
# 1 loop, best of 1: 4.25 s per loop
# s++ 100 18500
# 1 loop, best of 1: 6.15 s per loop
# s++ 100 19500
# 1 loop, best of 1: 5.64 s per loop
# p++ 100 500
# 1 loop, best of 1: 851 ms per loop
# p++ 100 1500
# 1 loop, best of 1: 770 ms per loop
# p++ 100 2500
# 1 loop, best of 1: 3.08 s per loop
# p++ 100 3500
# 1 loop, best of 1: 4.5 s per loop
# p++ 100 4500
# 1 loop, best of 1: 1.54 s per loop
# p++ 100 5500
# 1 loop, best of 1: 1.14 s per loop
# p++ 100 6500
# 1 loop, best of 1: 2.51 s per loop
# p++ 100 7500
# 1 loop, best of 1: 1.4 s per loop
# p++ 100 8500
# 1 loop, best of 1: 1.52 s per loop
# p++ 100 9500
# 1 loop, best of 1: 2.03 s per loop
# p++ 100 10500
# 1 loop, best of 1: 1.74 s per loop
# p++ 100 11500
# 1 loop, best of 1: 1.25 s per loop
# p++ 100 12500
# 1 loop, best of 1: 19.2 s per loop
# p++ 100 13500
# 1 loop, best of 1: 5.08 s per loop
# p++ 100 14500
# 1 loop, best of 1: 2.45 s per loop
# p++ 100 15500
# 1 loop, best of 1: 1.91 s per loop
# p++ 100 16500
# 1 loop, best of 1: 2.15 s per loop
# p++ 100 17500
# 1 loop, best of 1: 3.12 s per loop
# p++ 100 18500
# 1 loop, best of 1: 3.47 s per loop
# p++ 100 19500
# 1 loop, best of 1: 4.03 s per loop
# s++ 1 500
# 1 loop, best of 1: 110 ms per loop
# s++ 1 1500
# 1 loop, best of 1: 350 ms per loop
# s++ 1 2500
# 1 loop, best of 1: 637 ms per loop
# s++ 1 3500
# 1 loop, best of 1: 1.47 s per loop
# s++ 1 4500
# 1 loop, best of 1: 742 ms per loop
# s++ 1 5500
# 1 loop, best of 1: 2.88 s per loop
# s++ 1 6500
# 1 loop, best of 1: 1.25 s per loop
# s++ 1 7500
# 1 loop, best of 1: 9.14 s per loop
# s++ 1 8500
# 1 loop, best of 1: 4.47 s per loop
# s++ 1 9500
# 1 loop, best of 1: 11.8 s per loop
# s++ 1 10500
# 1 loop, best of 1: 10.2 s per loop
# s++ 1 11500
# 1 loop, best of 1: 4.74 s per loop
# s++ 1 12500
# 1 loop, best of 1: 2.05 s per loop
# s++ 1 13500
# 1 loop, best of 1: 12.6 s per loop
# s++ 1 14500
# 1 loop, best of 1: 11.2 s per loop
# s++ 1 15500
# 1 loop, best of 1: 7.68 s per loop
# s++ 1 16500
# 1 loop, best of 1: 4.52 s per loop
# s++ 1 17500
# 1 loop, best of 1: 3.84 s per loop
# s++ 1 18500
# 1 loop, best of 1: 5.59 s per loop
# s++ 1 19500
# 1 loop, best of 1: 3.16 s per loop
# p++ four engines 1 500
# 1 loop, best of 1: 488 ms per loop
# p++ four engines 1 1500
# 1 loop, best of 1: 988 ms per loop
# p++ four engines 1 2500
# 1 loop, best of 1: 1.84 s per loop
# p++ four engines 1 3500
# 1 loop, best of 1: 2.36 s per loop
# p++ four engines 1 4500
# 1 loop, best of 1: 1.3 s per loop
# p++ four engines 1 5500
# 1 loop, best of 1: 2.31 s per loop
# p++ four engines 1 6500
# 1 loop, best of 1: 3.5 s per loop
# p++ four engines 1 7500
# 1 loop, best of 1: 1.58 s per loop
# p++ four engines 1 8500
# 1 loop, best of 1: 1.51 s per loop
# p++ four engines 1 9500
# 1 loop, best of 1: 5.86 s per loop
# p++ four engines 1 10500
# 1 loop, best of 1: 2.42 s per loop
# p++ four engines 1 11500
# 1 loop, best of 1: 2.15 s per loop
# p++ four engines 1 12500
# 1 loop, best of 1: 3.48 s per loop
# p++ four engines 1 13500
# 1 loop, best of 1: 11.9 s per loop
# p++ four engines 1 14500
# 1 loop, best of 1: 11.8 s per loop
# p++ four engines 1 15500
# 1 loop, best of 1: 6.14 s per loop
# p++ four engines 1 16500
# 1 loop, best of 1: 15.6 s per loop
# p++ four engines 1 17500
# 1 loop, best of 1: 3.58 s per loop
# p++ four engines 1 18500
# 1 loop, best of 1: 5.39 s per loop
# p++ four engines 1 19500
# 1 loop, best of 1: 2.89 s per loop
# p++ three engines 1 500
# 1 loop, best of 1: 773 ms per loop
# p++ three engines 1 1500
# 1 loop, best of 1: 885 ms per loop
# p++ three engines 1 2500
# 1 loop, best of 1: 1.53 s per loop
# p++ three engines 1 3500
# 1 loop, best of 1: 3.55 s per loop
# p++ three engines 1 4500
# 1 loop, best of 1: 1.61 s per loop
# p++ three engines 1 5500
# 1 loop, best of 1: 2.54 s per loop
# p++ three engines 1 6500
# 1 loop, best of 1: 1.47 s per loop
# p++ three engines 1 7500
# 1 loop, best of 1: 1.72 s per loop
# p++ three engines 1 8500
# 1 loop, best of 1: 1.54 s per loop
# p++ three engines 1 9500
# 1 loop, best of 1: 5.46 s per loop
# p++ three engines 1 10500
# 1 loop, best of 1: 1.71 s per loop
# p++ three engines 1 11500
# 1 loop, best of 1: 2.4 s per loop
# p++ three engines 1 12500
# 1 loop, best of 1: 1.91 s per loop
# p++ three engines 1 13500
# 1 loop, best of 1: 8.67 s per loop
# p++ three engines 1 14500
# 1 loop, best of 1: 6.58 s per loop
# p++ three engines 1 15500
# 1 loop, best of 1: 3.63 s per loop
# p++ three engines 1 16500
# 1 loop, best of 1: 4.05 s per loop
# p++ three engines 1 17500
# 1 loop, best of 1: 7.5 s per loop
# p++ three engines 1 18500
# 1 loop, best of 1: 8.09 s per loop
# p++ three engines 1 19500
# 1 loop, best of 1: 3.96 s per loop
# p++ two engines 1 500
# 1 loop, best of 1: 1.12 s per loop
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-126-3362c09464c5> in <module>()
#     240         print("p++ two engines",u, len(XX[i]))
#     241         z = get_ipython().magic('timeit -n1 -r1 -o pk_means(XX[i], rk, e_all, seeding="k++", ReturnPlot = False)')
# --> 242         ts2[i,4] = z.best
#     243
#     244     if u == 1:
#
# IndexError: index 4 is out of bounds for axis 1 with size 3

# %%
#####################################################################
#Speed experiment: K-means++, serial vs parallel, different #engines#
#####################################################################

from matplotlib.offsetbox import AnchoredText
dataset_size = np.arange(500,20000,1000)

#Average over many random datasets:
rloops = 40

#######
# k=5 #
#######
rk = 5

for u in range(1,rloops+1):
    XX = create_data(dataset_size, rk)
    lds = len(dataset_size)

    #RECORD TIMINGS
    ts9 = np.zeros([lds,5],)
    ts9[:,0]=dataset_size

    #serial k means plus plus
    for i in range(0,lds):
        print("s++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o sk_means(XX[i], rk, seeding="k++", ReturnPlot = False)
        ts9[i,1] = z.best

    #parallel k means plus plus, all engines
    for i in range(0,lds):
        print("p++ four engines",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, e_odd, seeding="k++", ReturnPlot = False)
        ts9[i,2] = z.best
    
    #parallel k means plus plus, three engines
    for i in range(0,lds):
        print("p++ three engines",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, e_three, seeding="k++", ReturnPlot = False)
        ts9[i,3] = z.best

    #parallel k means plus plus, two engines
    for i in range(0,lds):
        print("p++ two engines",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, e_all, seeding="k++", ReturnPlot = False)
        ts9[i,4] = z.best
        
    if u == 1:
        tst9 = ts9
    else:
        tst9 = np.dstack((tst9,ts9))

#calculate mean values
ts9 = numpy.mean(tst9, axis=2)


################
#     plot     #
################
feng, ax = plt.subplots(1, figsize=(8,5))

ax.plot(ts9[:,0], ts9[:,1], 'r--', label="Serial execution K-means++")
ax.plot(ts9[:,0], ts9[:,2], 'c--', label="Parallel execution K-means++ two engines")
ax.plot(ts9[:,0], ts9[:,3], linestyle='--', color='DarkSlateBlue', label="Parallel execution K-means++ three engines")
ax.plot(ts9[:,0], ts9[:,4], 'b--', label="Parallel execution K-means++ four engine")

ax.set_title("Execution speeds of K-means++ Clustering: Comparing engines")
ax.set_xlabel("data set size")
ax.set_ylabel("execution time (s)")
ax.legend();

feng.savefig("f_skmeans_vs_pkmeans_quad.jpg", format="jpg", bbox_inches="tight")
feng.savefig("f_skmeans_vs_pkmeans_quad.eps", format="eps", bbox_inches="tight")

#plt.savefig("f_skmeans_vs_pkmeans_dual.jpg", format="jpg", bbox_inches="tight")
#plt.savefig("f_skmeans_vs_pkmeans_dual.eps", format="eps", bbox_inches="tight")
# Out:
# s++ 1 500
# 1 loop, best of 1: 961 ms per loop
# s++ 1 1500
# 1 loop, best of 1: 2.02 s per loop
# s++ 1 2500
# 1 loop, best of 1: 2.11 s per loop
# s++ 1 3500
# 1 loop, best of 1: 7.23 s per loop
# s++ 1 4500
# 1 loop, best of 1: 7.65 s per loop
# s++ 1 5500
# 1 loop, best of 1: 17.9 s per loop
# s++ 1 6500
# 1 loop, best of 1: 8.77 s per loop
# s++ 1 7500
# 1 loop, best of 1: 10.8 s per loop
# s++ 1 8500
# 1 loop, best of 1: 8.34 s per loop
# s++ 1 9500
# 1 loop, best of 1: 8.84 s per loop
# s++ 1 10500
# 1 loop, best of 1: 19.1 s per loop
# s++ 1 11500
# 1 loop, best of 1: 58.4 s per loop
# s++ 1 12500
# 1 loop, best of 1: 7.82 s per loop
# s++ 1 13500
# 1 loop, best of 1: 7.21 s per loop
# s++ 1 14500
# 1 loop, best of 1: 41.7 s per loop
# s++ 1 15500
# 1 loop, best of 1: 8.53 s per loop
# s++ 1 16500
# 1 loop, best of 1: 28.5 s per loop
# s++ 1 17500
# 1 loop, best of 1: 14.4 s per loop
# s++ 1 18500
# 1 loop, best of 1: 57.1 s per loop
# s++ 1 19500
# 1 loop, best of 1: 13.4 s per loop
# p++ four engines 1 500
# 1 loop, best of 1: 1.75 s per loop
# p++ four engines 1 1500
# 1 loop, best of 1: 2.4 s per loop
# p++ four engines 1 2500
# 1 loop, best of 1: 2.31 s per loop
# p++ four engines 1 3500
# 1 loop, best of 1: 7.05 s per loop
# p++ four engines 1 4500
# 1 loop, best of 1: 8.03 s per loop
# p++ four engines 1 5500
# 1 loop, best of 1: 18.2 s per loop
# p++ four engines 1 6500
# 1 loop, best of 1: 8.77 s per loop
# p++ four engines 1 7500
# 1 loop, best of 1: 9.73 s per loop
# p++ four engines 1 8500
# 1 loop, best of 1: 8.73 s per loop
# p++ four engines 1 9500
# 1 loop, best of 1: 7.86 s per loop
# p++ four engines 1 10500
# 1 loop, best of 1: 17.7 s per loop
# p++ four engines 1 11500
# 1 loop, best of 1: 44.5 s per loop
# p++ four engines 1 12500
# 1 loop, best of 1: 7.96 s per loop
# p++ four engines 1 13500
# 1 loop, best of 1: 6.81 s per loop
# p++ four engines 1 14500
# 1 loop, best of 1: 36.7 s per loop
# p++ four engines 1 15500
# 1 loop, best of 1: 8.34 s per loop
# p++ four engines 1 16500
# 1 loop, best of 1: 26.2 s per loop
# p++ four engines 1 17500
# 1 loop, best of 1: 12.5 s per loop
# p++ four engines 1 18500
# 1 loop, best of 1: 49.4 s per loop
# p++ four engines 1 19500
# 1 loop, best of 1: 11.3 s per loop
# p++ three engines 1 500
# 1 loop, best of 1: 1.33 s per loop
# p++ three engines 1 1500
# 1 loop, best of 1: 2.33 s per loop
# p++ three engines 1 2500
# 1 loop, best of 1: 3.41 s per loop
# p++ three engines 1 3500
# 1 loop, best of 1: 7.72 s per loop
# p++ three engines 1 4500
# 1 loop, best of 1: 9.06 s per loop
# p++ three engines 1 5500
# 1 loop, best of 1: 18.1 s per loop
# p++ three engines 1 6500
# 1 loop, best of 1: 8.03 s per loop
# p++ three engines 1 7500
# 1 loop, best of 1: 10.4 s per loop
# p++ three engines 1 8500
# 1 loop, best of 1: 8.13 s per loop
# p++ three engines 1 9500
# 1 loop, best of 1: 8.64 s per loop
# p++ three engines 1 10500
# 1 loop, best of 1: 18.1 s per loop
# p++ three engines 1 11500
# 1 loop, best of 1: 43.7 s per loop
# p++ three engines 1 12500
# 1 loop, best of 1: 7.18 s per loop
# p++ three engines 1 13500
# 1 loop, best of 1: 7.44 s per loop
# p++ three engines 1 14500
# 1 loop, best of 1: 35.2 s per loop
# p++ three engines 1 15500
# 1 loop, best of 1: 7.62 s per loop
# p++ three engines 1 16500
# 1 loop, best of 1: 25.1 s per loop
# p++ three engines 1 17500
# 1 loop, best of 1: 13 s per loop
# p++ three engines 1 18500
# 1 loop, best of 1: 47.7 s per loop
# p++ three engines 1 19500
# 1 loop, best of 1: 11.1 s per loop
# p++ two engines 1 500
# 1 loop, best of 1: 1.82 s per loop
# p++ two engines 1 1500
# 1 loop, best of 1: 2.91 s per loop
# p++ two engines 1 2500
# 1 loop, best of 1: 3.04 s per loop
# p++ two engines 1 3500
# 1 loop, best of 1: 9.54 s per loop
# p++ two engines 1 4500
# 1 loop, best of 1: 9.27 s per loop
# p++ two engines 1 5500
# 1 loop, best of 1: 19.4 s per loop
# p++ two engines 1 6500
# 1 loop, best of 1: 9.37 s per loop
# p++ two engines 1 7500
# 1 loop, best of 1: 10.7 s per loop
# p++ two engines 1 8500
# 1 loop, best of 1: 8.45 s per loop
# p++ two engines 1 9500
# 1 loop, best of 1: 9.16 s per loop
# p++ two engines 1 10500
# 1 loop, best of 1: 18.2 s per loop
# p++ two engines 1 11500
# 1 loop, best of 1: 44.7 s per loop
# p++ two engines 1 12500
# 1 loop, best of 1: 7.18 s per loop
# p++ two engines 1 13500
# 1 loop, best of 1: 7.78 s per loop
# p++ two engines 1 14500
# 1 loop, best of 1: 36.9 s per loop
# p++ two engines 1 15500
# 1 loop, best of 1: 7.7 s per loop
# p++ two engines 1 16500
# 1 loop, best of 1: 25.8 s per loop
# p++ two engines 1 17500
# 1 loop, best of 1: 13.6 s per loop
# p++ two engines 1 18500
# 1 loop, best of 1: 49.1 s per loop
# p++ two engines 1 19500
# 1 loop, best of 1: 11.5 s per loop
# s++ 2 500
# 1 loop, best of 1: 447 ms per loop
# s++ 2 1500
# 1 loop, best of 1: 1.87 s per loop
# s++ 2 2500
# 1 loop, best of 1: 1.63 s per loop
# s++ 2 3500
# 1 loop, best of 1: 4.25 s per loop
# s++ 2 4500
# 1 loop, best of 1: 7.14 s per loop
# s++ 2 5500
# 1 loop, best of 1: 5.11 s per loop
# s++ 2 6500
# 1 loop, best of 1: 8.97 s per loop
# s++ 2 7500
# 1 loop, best of 1: 32.8 s per loop
# s++ 2 8500
# 1 loop, best of 1: 14.7 s per loop
# s++ 2 9500
# 1 loop, best of 1: 4.47 s per loop
# s++ 2 10500
# 1 loop, best of 1: 1min 1s per loop
# s++ 2 11500
# 1 loop, best of 1: 14.4 s per loop
# s++ 2 12500
# 1 loop, best of 1: 6.86 s per loop
# s++ 2 13500
# 1 loop, best of 1: 12.8 s per loop
# s++ 2 14500
# 1 loop, best of 1: 35.5 s per loop
# s++ 2 15500
# 1 loop, best of 1: 1min 4s per loop
# s++ 2 16500
# 1 loop, best of 1: 28.7 s per loop
# s++ 2 17500
# 1 loop, best of 1: 30.6 s per loop
# s++ 2 18500
# 1 loop, best of 1: 1min 26s per loop
# s++ 2 19500
# 1 loop, best of 1: 20.6 s per loop
# p++ four engines 2 500
# 1 loop, best of 1: 858 ms per loop
# p++ four engines 2 1500
# 1 loop, best of 1: 2.97 s per loop
# p++ four engines 2 2500
# 1 loop, best of 1: 1.98 s per loop
# p++ four engines 2 3500
# 1 loop, best of 1: 4.68 s per loop
# p++ four engines 2 4500
# 1 loop, best of 1: 5.66 s per loop
# p++ four engines 2 5500
# 1 loop, best of 1: 5.46 s per loop
# p++ four engines 2 6500
# 1 loop, best of 1: 7.79 s per loop
# p++ four engines 2 7500
# 1 loop, best of 1: 29.9 s per loop
# p++ four engines 2 8500
# 1 loop, best of 1: 13.7 s per loop
# p++ four engines 2 9500
# 1 loop, best of 1: 4.07 s per loop
# p++ four engines 2 10500
# 1 loop, best of 1: 53.6 s per loop
# p++ four engines 2 11500
# 1 loop, best of 1: 12 s per loop
# p++ four engines 2 12500
# 1 loop, best of 1: 6.87 s per loop
# p++ four engines 2 13500
# 1 loop, best of 1: 11.1 s per loop
# p++ four engines 2 14500
# 1 loop, best of 1: 28.8 s per loop
# p++ four engines 2 15500
# 1 loop, best of 1: 54.8 s per loop
# p++ four engines 2 16500
# 1 loop, best of 1: 24.4 s per loop
# p++ four engines 2 17500
# 1 loop, best of 1: 25.7 s per loop
# p++ four engines 2 18500
# 1 loop, best of 1: 1min 11s per loop
# p++ four engines 2 19500
# 1 loop, best of 1: 17.7 s per loop
# p++ three engines 2 500
# 1 loop, best of 1: 1.16 s per loop
# p++ three engines 2 1500
# 1 loop, best of 1: 3.7 s per loop
# p++ three engines 2 2500
# 1 loop, best of 1: 2.16 s per loop
# p++ three engines 2 3500
# 1 loop, best of 1: 4.61 s per loop
# p++ three engines 2 4500
# 1 loop, best of 1: 5.99 s per loop
# p++ three engines 2 5500
# 1 loop, best of 1: 5.54 s per loop
# p++ three engines 2 6500
# 1 loop, best of 1: 7.89 s per loop
# p++ three engines 2 7500
# 1 loop, best of 1: 30.4 s per loop
# p++ three engines 2 8500
# 1 loop, best of 1: 13.6 s per loop
# p++ three engines 2 9500
# 1 loop, best of 1: 4.12 s per loop
# p++ three engines 2 10500
# 1 loop, best of 1: 53.5 s per loop
# p++ three engines 2 11500
# 1 loop, best of 1: 12.3 s per loop
# p++ three engines 2 12500
# 1 loop, best of 1: 6.78 s per loop
# p++ three engines 2 13500
# 1 loop, best of 1: 11.5 s per loop
# p++ three engines 2 14500
# 1 loop, best of 1: 28.5 s per loop
# p++ three engines 2 15500
# 1 loop, best of 1: 53.7 s per loop
# p++ three engines 2 16500
# 1 loop, best of 1: 23.2 s per loop
# p++ three engines 2 17500
# 1 loop, best of 1: 25.4 s per loop
# p++ three engines 2 18500
# 1 loop, best of 1: 1min 9s per loop
# p++ three engines 2 19500
# 1 loop, best of 1: 17.2 s per loop
# p++ two engines 2 500
# 1 loop, best of 1: 1.19 s per loop
# p++ two engines 2 1500
# 1 loop, best of 1: 3.75 s per loop
# p++ two engines 2 2500
# 1 loop, best of 1: 2.9 s per loop
# p++ two engines 2 3500
# 1 loop, best of 1: 5.41 s per loop
# p++ two engines 2 4500
# 1 loop, best of 1: 6.22 s per loop
# p++ two engines 2 5500
# 1 loop, best of 1: 6.37 s per loop
# p++ two engines 2 6500
# 1 loop, best of 1: 8.43 s per loop
# p++ two engines 2 7500
# 1 loop, best of 1: 31.4 s per loop
# p++ two engines 2 8500
# 1 loop, best of 1: 14.5 s per loop
# p++ two engines 2 9500
# 1 loop, best of 1: 4.79 s per loop
# p++ two engines 2 10500
# 1 loop, best of 1: 54.4 s per loop
# p++ two engines 2 11500
# 1 loop, best of 1: 13.3 s per loop
# p++ two engines 2 12500
# 1 loop, best of 1: 7.39 s per loop
# p++ two engines 2 13500
# 1 loop, best of 1: 12.2 s per loop
# p++ two engines 2 14500
# 1 loop, best of 1: 31 s per loop
# p++ two engines 2 15500
# 1 loop, best of 1: 54.3 s per loop
# p++ two engines 2 16500
# 1 loop, best of 1: 24.7 s per loop
# p++ two engines 2 17500
# 1 loop, best of 1: 25.1 s per loop
# p++ two engines 2 18500
# 1 loop, best of 1: 1min 2s per loop
# p++ two engines 2 19500
# 1 loop, best of 1: 14.9 s per loop
# s++ 3 500
# 1 loop, best of 1: 433 ms per loop
# s++ 3 1500
# 1 loop, best of 1: 712 ms per loop
# s++ 3 2500
# 1 loop, best of 1: 2.66 s per loop
# s++ 3 3500
# 1 loop, best of 1: 2.59 s per loop
# s++ 3 4500
# 1 loop, best of 1: 6.35 s per loop
# s++ 3 5500
# 1 loop, best of 1: 5.26 s per loop
# s++ 3 6500
# 1 loop, best of 1: 3.34 s per loop
# s++ 3 7500
# 1 loop, best of 1: 15.2 s per loop
# s++ 3 8500
# 1 loop, best of 1: 5.44 s per loop
# s++ 3 9500
# 1 loop, best of 1: 15 s per loop
# s++ 3 10500
# 1 loop, best of 1: 14.4 s per loop
# s++ 3 11500
# 1 loop, best of 1: 17.7 s per loop
# s++ 3 12500
# 1 loop, best of 1: 25.5 s per loop
# s++ 3 13500
# 1 loop, best of 1: 14.1 s per loop
# s++ 3 14500
# 1 loop, best of 1: 14 s per loop
# s++ 3 15500
# 1 loop, best of 1: 28.9 s per loop
# s++ 3 16500
# 1 loop, best of 1: 14.5 s per loop
# s++ 3 17500
# 1 loop, best of 1: 15.2 s per loop
# s++ 3 18500
# 1 loop, best of 1: 8.52 s per loop
# s++ 3 19500
# 1 loop, best of 1: 9.32 s per loop
# p++ four engines 3 500
# 1 loop, best of 1: 1.11 s per loop
# p++ four engines 3 1500
# 1 loop, best of 1: 1 s per loop
# p++ four engines 3 2500
# 1 loop, best of 1: 2.56 s per loop
# p++ four engines 3 3500
# 1 loop, best of 1: 3.27 s per loop
# p++ four engines 3 4500
# 1 loop, best of 1: 6.59 s per loop
# p++ four engines 3 5500
# 1 loop, best of 1: 4.89 s per loop
# p++ four engines 3 6500
# 1 loop, best of 1: 3.06 s per loop
# p++ four engines 3 7500
# 1 loop, best of 1: 13.9 s per loop
# p++ four engines 3 8500
# 1 loop, best of 1: 5.95 s per loop
# p++ four engines 3 9500
# 1 loop, best of 1: 12.7 s per loop
# p++ four engines 3 10500
# 1 loop, best of 1: 12.5 s per loop
# p++ four engines 3 11500
# 1 loop, best of 1: 15.8 s per loop
# p++ four engines 3 12500
# 1 loop, best of 1: 22.1 s per loop
# p++ four engines 3 13500
# 1 loop, best of 1: 11.9 s per loop
# p++ four engines 3 14500
# 1 loop, best of 1: 12.2 s per loop
# p++ four engines 3 15500
# 1 loop, best of 1: 24.5 s per loop
# p++ four engines 3 16500
# 1 loop, best of 1: 11.6 s per loop
# p++ four engines 3 17500
# 1 loop, best of 1: 13.3 s per loop
# p++ four engines 3 18500
# 1 loop, best of 1: 8.4 s per loop
# p++ four engines 3 19500
# 1 loop, best of 1: 7.98 s per loop
# p++ three engines 3 500
# 1 loop, best of 1: 1.58 s per loop
# p++ three engines 3 1500
# 1 loop, best of 1: 1.29 s per loop
# p++ three engines 3 2500
# 1 loop, best of 1: 3.61 s per loop
# p++ three engines 3 3500
# 1 loop, best of 1: 3.12 s per loop
# p++ three engines 3 4500
# 1 loop, best of 1: 6.48 s per loop
# p++ three engines 3 5500
# 1 loop, best of 1: 5.8 s per loop
# p++ three engines 3 6500
# 1 loop, best of 1: 3.26 s per loop
# p++ three engines 3 7500
# 1 loop, best of 1: 14.3 s per loop
# p++ three engines 3 8500
# 1 loop, best of 1: 5.21 s per loop
# p++ three engines 3 9500
# 1 loop, best of 1: 13.3 s per loop
# p++ three engines 3 10500
# 1 loop, best of 1: 12.6 s per loop
# p++ three engines 3 11500
# 1 loop, best of 1: 15.6 s per loop
# p++ three engines 3 12500
# 1 loop, best of 1: 21.3 s per loop
# p++ three engines 3 13500
# 1 loop, best of 1: 12.4 s per loop
# p++ three engines 3 14500
# 1 loop, best of 1: 12.2 s per loop
# p++ three engines 3 15500
# 1 loop, best of 1: 23.4 s per loop
# p++ three engines 3 16500
# 1 loop, best of 1: 12.5 s per loop
# p++ three engines 3 17500
# 1 loop, best of 1: 12.7 s per loop
# p++ three engines 3 18500
# 1 loop, best of 1: 7.89 s per loop
# p++ three engines 3 19500
# 1 loop, best of 1: 8.33 s per loop
# p++ two engines 3 500
# 1 loop, best of 1: 2.13 s per loop
# p++ two engines 3 1500
# 1 loop, best of 1: 1.49 s per loop
# p++ two engines 3 2500
# 1 loop, best of 1: 3.08 s per loop
# p++ two engines 3 3500
# 1 loop, best of 1: 3.31 s per loop
# p++ two engines 3 4500
# 1 loop, best of 1: 7.72 s per loop
# p++ two engines 3 5500
# 1 loop, best of 1: 5.64 s per loop
# p++ two engines 3 6500
# 1 loop, best of 1: 3.23 s per loop
# p++ two engines 3 7500
# 1 loop, best of 1: 15 s per loop
# p++ two engines 3 8500
# 1 loop, best of 1: 5.94 s per loop
# p++ two engines 3 9500
# 1 loop, best of 1: 13.4 s per loop
# p++ two engines 3 10500
# 1 loop, best of 1: 13.3 s per loop
# p++ two engines 3 11500
# 1 loop, best of 1: 16.2 s per loop
# p++ two engines 3 12500
# 1 loop, best of 1: 22.7 s per loop
# p++ two engines 3 13500
# 1 loop, best of 1: 12.5 s per loop
# p++ two engines 3 14500
# 1 loop, best of 1: 12.5 s per loop
# p++ two engines 3 15500
# 1 loop, best of 1: 24.2 s per loop
# p++ two engines 3 16500
# 1 loop, best of 1: 12.1 s per loop
# p++ two engines 3 17500
# 1 loop, best of 1: 13.2 s per loop
# p++ two engines 3 18500
# 1 loop, best of 1: 8.36 s per loop
# p++ two engines 3 19500
# 1 loop, best of 1: 7.86 s per loop
# s++ 4 500
# 1 loop, best of 1: 292 ms per loop
# s++ 4 1500
# 1 loop, best of 1: 2.2 s per loop
# s++ 4 2500
# 1 loop, best of 1: 1.58 s per loop
# s++ 4 3500
# 1 loop, best of 1: 4.76 s per loop
# s++ 4 4500
# 1 loop, best of 1: 5.57 s per loop
# s++ 4 5500
# 1 loop, best of 1: 9.19 s per loop
# s++ 4 6500
# 1 loop, best of 1: 8 s per loop
# s++ 4 7500
# 1 loop, best of 1: 31.7 s per loop
# s++ 4 8500
# 1 loop, best of 1: 22.4 s per loop
# s++ 4 9500
# 1 loop, best of 1: 14.1 s per loop
# s++ 4 10500
# 1 loop, best of 1: 14 s per loop
# s++ 4 11500
# 1 loop, best of 1: 20.7 s per loop
# s++ 4 12500
# 1 loop, best of 1: 34.5 s per loop
# s++ 4 13500
# 1 loop, best of 1: 59.5 s per loop
# s++ 4 14500
# 1 loop, best of 1: 10.8 s per loop
# s++ 4 15500
# 1 loop, best of 1: 16.6 s per loop
# s++ 4 16500
# 1 loop, best of 1: 54.2 s per loop
# s++ 4 17500
# 1 loop, best of 1: 48.7 s per loop
# s++ 4 18500
# 1 loop, best of 1: 26.8 s per loop
# s++ 4 19500
# 1 loop, best of 1: 1min 11s per loop
# p++ four engines 4 500
# 1 loop, best of 1: 753 ms per loop
# p++ four engines 4 1500
# 1 loop, best of 1: 2.63 s per loop
# p++ four engines 4 2500
# 1 loop, best of 1: 1.44 s per loop
# p++ four engines 4 3500
# 1 loop, best of 1: 5.35 s per loop
# p++ four engines 4 4500
# 1 loop, best of 1: 5.7 s per loop
# p++ four engines 4 5500
# 1 loop, best of 1: 8.03 s per loop
# p++ four engines 4 6500
# 1 loop, best of 1: 8.28 s per loop
# p++ four engines 4 7500
# 1 loop, best of 1: 28.8 s per loop
# p++ four engines 4 8500
# 1 loop, best of 1: 19.4 s per loop
# p++ four engines 4 9500
# 1 loop, best of 1: 12.8 s per loop
# p++ four engines 4 10500
# 1 loop, best of 1: 12.8 s per loop
# p++ four engines 4 11500
# 1 loop, best of 1: 18 s per loop
# p++ four engines 4 12500
# 1 loop, best of 1: 29.2 s per loop
# p++ four engines 4 13500
# 1 loop, best of 1: 49.7 s per loop
# p++ four engines 4 14500
# 1 loop, best of 1: 9.36 s per loop
# p++ four engines 4 15500
# 1 loop, best of 1: 14.6 s per loop
# p++ four engines 4 16500
# 1 loop, best of 1: 44.9 s per loop
# p++ four engines 4 17500
# 1 loop, best of 1: 39.9 s per loop
# p++ four engines 4 18500
# 1 loop, best of 1: 23.3 s per loop
# p++ four engines 4 19500
# 1 loop, best of 1: 58.1 s per loop
# p++ three engines 4 500
# 1 loop, best of 1: 1.2 s per loop
# p++ three engines 4 1500
# 1 loop, best of 1: 3.38 s per loop
# p++ three engines 4 2500
# 1 loop, best of 1: 1.55 s per loop
# p++ three engines 4 3500
# 1 loop, best of 1: 5.16 s per loop
# p++ three engines 4 4500
# 1 loop, best of 1: 6.05 s per loop
# p++ three engines 4 5500
# 1 loop, best of 1: 8.41 s per loop
# p++ three engines 4 6500
# 1 loop, best of 1: 8.04 s per loop
# p++ three engines 4 7500
# 1 loop, best of 1: 28.1 s per loop
# p++ three engines 4 8500
# 1 loop, best of 1: 20.4 s per loop
# p++ three engines 4 9500
# 1 loop, best of 1: 11.9 s per loop
# p++ three engines 4 10500
# 1 loop, best of 1: 12.8 s per loop
# p++ three engines 4 11500
# 1 loop, best of 1: 17.4 s per loop
# p++ three engines 4 12500
# 1 loop, best of 1: 28.9 s per loop
# p++ three engines 4 13500
# 1 loop, best of 1: 48.8 s per loop
# p++ three engines 4 14500
# 1 loop, best of 1: 10.2 s per loop
# p++ three engines 4 15500
# 1 loop, best of 1: 14.2 s per loop
# p++ three engines 4 16500
# 1 loop, best of 1: 42.4 s per loop
# p++ three engines 4 17500
# 1 loop, best of 1: 39.4 s per loop
# p++ three engines 4 18500
# 1 loop, best of 1: 22.1 s per loop
# p++ three engines 4 19500
# 1 loop, best of 1: 57.2 s per loop
# p++ two engines 4 500
# 1 loop, best of 1: 1.23 s per loop
# p++ two engines 4 1500
# 1 loop, best of 1: 3.55 s per loop
# p++ two engines 4 2500
# 1 loop, best of 1: 1.77 s per loop
# p++ two engines 4 3500
# 1 loop, best of 1: 5.95 s per loop
# p++ two engines 4 4500
# 1 loop, best of 1: 6.8 s per loop
# p++ two engines 4 5500
# 1 loop, best of 1: 8.86 s per loop
# p++ two engines 4 6500
# 1 loop, best of 1: 8.55 s per loop
# p++ two engines 4 7500
# 1 loop, best of 1: 30.2 s per loop
# p++ two engines 4 8500
# 1 loop, best of 1: 20 s per loop
# p++ two engines 4 9500
# 1 loop, best of 1: 13.1 s per loop
# p++ two engines 4 10500
# 1 loop, best of 1: 13.4 s per loop
# p++ two engines 4 11500
# 1 loop, best of 1: 18.1 s per loop
# p++ two engines 4 12500
# 1 loop, best of 1: 30.4 s per loop
# p++ two engines 4 13500
# 1 loop, best of 1: 49.7 s per loop
# p++ two engines 4 14500
# 1 loop, best of 1: 10 s per loop
# p++ two engines 4 15500
# 1 loop, best of 1: 14.2 s per loop
# p++ two engines 4 16500
# 1 loop, best of 1: 44.9 s per loop
# p++ two engines 4 17500
# 1 loop, best of 1: 40.5 s per loop
# p++ two engines 4 18500
# 1 loop, best of 1: 22 s per loop
# p++ two engines 4 19500
# 1 loop, best of 1: 57.7 s per loop
# s++ 5 500
# 1 loop, best of 1: 344 ms per loop
# s++ 5 1500
# 1 loop, best of 1: 3.34 s per loop
# s++ 5 2500
# 1 loop, best of 1: 1.14 s per loop
# s++ 5 3500
# 1 loop, best of 1: 6.34 s per loop
# s++ 5 4500
# 1 loop, best of 1: 2.99 s per loop
# s++ 5 5500
# 1 loop, best of 1: 16.6 s per loop
# s++ 5 6500
# 1 loop, best of 1: 4.8 s per loop
# s++ 5 7500
# 1 loop, best of 1: 13.9 s per loop
# s++ 5 8500
# 1 loop, best of 1: 10.1 s per loop
# s++ 5 9500
# 1 loop, best of 1: 15.5 s per loop
# s++ 5 10500
# 1 loop, best of 1: 15 s per loop
# s++ 5 11500
# 1 loop, best of 1: 1min 12s per loop
# s++ 5 12500
# 1 loop, best of 1: 8.42 s per loop
# s++ 5 13500
# 1 loop, best of 1: 8.99 s per loop
# s++ 5 14500
# 1 loop, best of 1: 20.9 s per loop
# s++ 5 15500
# 1 loop, best of 1: 6.11 s per loop
# s++ 5 16500
# 1 loop, best of 1: 10.7 s per loop
# s++ 5 17500
# 1 loop, best of 1: 1min 15s per loop
# s++ 5 18500
# 1 loop, best of 1: 1min 59s per loop
# s++ 5 19500
# 1 loop, best of 1: 2min 44s per loop
# p++ four engines 5 500
# 1 loop, best of 1: 873 ms per loop
# p++ four engines 5 1500
# 1 loop, best of 1: 4.69 s per loop
# p++ four engines 5 2500
# 1 loop, best of 1: 1.45 s per loop
# p++ four engines 5 3500
# 1 loop, best of 1: 6.97 s per loop
# p++ four engines 5 4500
# 1 loop, best of 1: 3.03 s per loop
# p++ four engines 5 5500
# 1 loop, best of 1: 16.4 s per loop
# p++ four engines 5 6500
# 1 loop, best of 1: 4.62 s per loop
# p++ four engines 5 7500
# 1 loop, best of 1: 13 s per loop
# p++ four engines 5 8500
# 1 loop, best of 1: 9.44 s per loop
# p++ four engines 5 9500
# 1 loop, best of 1: 13.6 s per loop
# p++ four engines 5 10500
# 1 loop, best of 1: 13.3 s per loop
# p++ four engines 5 11500
# 1 loop, best of 1: 1min 2s per loop
# p++ four engines 5 12500
# 1 loop, best of 1: 8.17 s per loop
# p++ four engines 5 13500
# 1 loop, best of 1: 7.61 s per loop
# p++ four engines 5 14500
# 1 loop, best of 1: 18 s per loop
# p++ four engines 5 15500
# 1 loop, best of 1: 6.03 s per loop
# p++ four engines 5 16500
# 1 loop, best of 1: 9.21 s per loop
# p++ four engines 5 17500
# 1 loop, best of 1: 1min 3s per loop
# p++ four engines 5 18500
# 1 loop, best of 1: 1min 36s per loop
# p++ four engines 5 19500
# 1 loop, best of 1: 2min 7s per loop
# p++ three engines 5 500
# 1 loop, best of 1: 1.15 s per loop
# p++ three engines 5 1500
# 1 loop, best of 1: 5.97 s per loop
# p++ three engines 5 2500
# 1 loop, best of 1: 1.79 s per loop
# p++ three engines 5 3500
# 1 loop, best of 1: 6.67 s per loop
# p++ three engines 5 4500
# 1 loop, best of 1: 3.47 s per loop
# p++ three engines 5 5500
# 1 loop, best of 1: 16.4 s per loop
# p++ three engines 5 6500
# 1 loop, best of 1: 5.54 s per loop
# p++ three engines 5 7500
# 1 loop, best of 1: 12.7 s per loop
# p++ three engines 5 8500
# 1 loop, best of 1: 9 s per loop
# p++ three engines 5 9500
# 1 loop, best of 1: 14.2 s per loop
# p++ three engines 5 10500
# 1 loop, best of 1: 13.9 s per loop
# p++ three engines 5 11500
# 1 loop, best of 1: 1min 1s per loop
# p++ three engines 5 12500
# 1 loop, best of 1: 7.26 s per loop
# p++ three engines 5 13500
# 1 loop, best of 1: 8.69 s per loop
# p++ three engines 5 14500
# 1 loop, best of 1: 17.9 s per loop
# p++ three engines 5 15500
# 1 loop, best of 1: 5.2 s per loop
# p++ three engines 5 16500
# 1 loop, best of 1: 10.1 s per loop
# p++ three engines 5 17500
# 1 loop, best of 1: 54.6 s per loop
# p++ three engines 5 18500
# 1 loop, best of 1: 1min 19s per loop
# p++ three engines 5 19500
# 1 loop, best of 1: 1min 45s per loop
# p++ two engines 5 500
# 1 loop, best of 1: 1.35 s per loop
# p++ two engines 5 1500
# 1 loop, best of 1: 6.31 s per loop
# p++ two engines 5 2500
# 1 loop, best of 1: 1.84 s per loop
# p++ two engines 5 3500
# 1 loop, best of 1: 8.36 s per loop
# p++ two engines 5 4500
# 1 loop, best of 1: 3.43 s per loop
# p++ two engines 5 5500
# 1 loop, best of 1: 17.5 s per loop
# p++ two engines 5 6500
# 1 loop, best of 1: 5.28 s per loop
# p++ two engines 5 7500
# 1 loop, best of 1: 13.8 s per loop
# p++ two engines 5 8500
# 1 loop, best of 1: 10.2 s per loop
# p++ two engines 5 9500
# 1 loop, best of 1: 14.6 s per loop
# p++ two engines 5 10500
# 1 loop, best of 1: 13.9 s per loop
# p++ two engines 5 11500
# 1 loop, best of 1: 1min 3s per loop
# p++ two engines 5 12500
# 1 loop, best of 1: 7.42 s per loop
# p++ two engines 5 13500
# 1 loop, best of 1: 9.17 s per loop
# p++ two engines 5 14500
# 1 loop, best of 1: 18.3 s per loop
# p++ two engines 5 15500
# 1 loop, best of 1: 5.42 s per loop
# p++ two engines 5 16500
# 1 loop, best of 1: 10.2 s per loop
# p++ two engines 5 17500
# 1 loop, best of 1: 1min 1s per loop
# p++ two engines 5 18500
# 1 loop, best of 1: 1min 34s per loop
# p++ two engines 5 19500
# 1 loop, best of 1: 2min 3s per loop
# s++ 6 500
# 1 loop, best of 1: 680 ms per loop
# s++ 6 1500
# 1 loop, best of 1: 1.66 s per loop
# s++ 6 2500
# 1 loop, best of 1: 2.67 s per loop
# s++ 6 3500
# 1 loop, best of 1: 1.63 s per loop
# s++ 6 4500
# 1 loop, best of 1: 3.77 s per loop
# s++ 6 5500
# 1 loop, best of 1: 5.67 s per loop
# s++ 6 6500
# 1 loop, best of 1: 4.93 s per loop
# s++ 6 7500
# 1 loop, best of 1: 30.8 s per loop
# s++ 6 8500
# 1 loop, best of 1: 35.8 s per loop
# s++ 6 9500
# 1 loop, best of 1: 5.27 s per loop
# s++ 6 10500
# 1 loop, best of 1: 8.3 s per loop
# s++ 6 11500
# 1 loop, best of 1: 10.7 s per loop
# s++ 6 12500
# 1 loop, best of 1: 1min 17s per loop
# s++ 6 13500
# 1 loop, best of 1: 26.4 s per loop
# s++ 6 14500
# 1 loop, best of 1: 39.6 s per loop
# s++ 6 15500
# 1 loop, best of 1: 15 s per loop
# s++ 6 16500
# 1 loop, best of 1: 12.7 s per loop
# s++ 6 17500
# 1 loop, best of 1: 12.1 s per loop
# s++ 6 18500
# 1 loop, best of 1: 25 s per loop
# s++ 6 19500
# 1 loop, best of 1: 1min 9s per loop
# p++ four engines 6 500
# 1 loop, best of 1: 1.22 s per loop
# p++ four engines 6 1500
# 1 loop, best of 1: 1.59 s per loop
# p++ four engines 6 2500
# 1 loop, best of 1: 3.05 s per loop
# p++ four engines 6 3500
# 1 loop, best of 1: 1.91 s per loop
# p++ four engines 6 4500
# 1 loop, best of 1: 4.27 s per loop
# p++ four engines 6 5500
# 1 loop, best of 1: 6.08 s per loop
# p++ four engines 6 6500
# 1 loop, best of 1: 4.08 s per loop
# p++ four engines 6 7500
# 1 loop, best of 1: 28.3 s per loop
# p++ four engines 6 8500
# 1 loop, best of 1: 31.9 s per loop
# p++ four engines 6 9500
# 1 loop, best of 1: 4.76 s per loop
# p++ four engines 6 10500
# 1 loop, best of 1: 7.91 s per loop
# p++ four engines 6 11500
# 1 loop, best of 1: 9.34 s per loop
# p++ four engines 6 12500
# 1 loop, best of 1: 1min 6s per loop
# p++ four engines 6 13500
# 1 loop, best of 1: 24.4 s per loop
# p++ four engines 6 14500
# 1 loop, best of 1: 34.3 s per loop
# p++ four engines 6 15500
# 1 loop, best of 1: 13.5 s per loop
# p++ four engines 6 16500
# 1 loop, best of 1: 11.6 s per loop
# p++ four engines 6 17500
# 1 loop, best of 1: 10.2 s per loop
# p++ four engines 6 18500
# 1 loop, best of 1: 22.1 s per loop
# p++ four engines 6 19500
# 1 loop, best of 1: 55.9 s per loop
# p++ three engines 6 500
# 1 loop, best of 1: 1.66 s per loop
# p++ three engines 6 1500
# 1 loop, best of 1: 1.91 s per loop
# p++ three engines 6 2500
# 1 loop, best of 1: 4.32 s per loop
# p++ three engines 6 3500
# 1 loop, best of 1: 1.98 s per loop
# p++ three engines 6 4500
# 1 loop, best of 1: 4.06 s per loop
# p++ three engines 6 5500
# 1 loop, best of 1: 5.69 s per loop
# p++ three engines 6 6500
# 1 loop, best of 1: 5 s per loop
# p++ three engines 6 7500
# 1 loop, best of 1: 28.2 s per loop
# p++ three engines 6 8500
# 1 loop, best of 1: 32.1 s per loop
# p++ three engines 6 9500
# 1 loop, best of 1: 5.18 s per loop
# p++ three engines 6 10500
# 1 loop, best of 1: 7.11 s per loop
# p++ three engines 6 11500
# 1 loop, best of 1: 10.4 s per loop
# p++ three engines 6 12500
# 1 loop, best of 1: 1min 5s per loop
# p++ three engines 6 13500
# 1 loop, best of 1: 22.2 s per loop
# p++ three engines 6 14500
# 1 loop, best of 1: 33.5 s per loop
# p++ three engines 6 15500
# 1 loop, best of 1: 12.7 s per loop
# p++ three engines 6 16500
# 1 loop, best of 1: 10.8 s per loop
# p++ three engines 6 17500
# 1 loop, best of 1: 10.4 s per loop
# p++ three engines 6 18500
# 1 loop, best of 1: 21 s per loop
# p++ three engines 6 19500
# 1 loop, best of 1: 55.2 s per loop
# p++ two engines 6 500
# 1 loop, best of 1: 2.28 s per loop
# p++ two engines 6 1500
# 1 loop, best of 1: 2.62 s per loop
# p++ two engines 6 2500
# 1 loop, best of 1: 3.9 s per loop
# p++ two engines 6 3500
# 1 loop, best of 1: 2.11 s per loop
# p++ two engines 6 4500
# 1 loop, best of 1: 4.34 s per loop
# p++ two engines 6 5500
# 1 loop, best of 1: 7.02 s per loop
# p++ two engines 6 6500
# 1 loop, best of 1: 4.44 s per loop
# p++ two engines 6 7500
# 1 loop, best of 1: 30.3 s per loop
# p++ two engines 6 8500
# 1 loop, best of 1: 33.2 s per loop
# p++ two engines 6 9500
# 1 loop, best of 1: 5.18 s per loop
# p++ two engines 6 10500
# 1 loop, best of 1: 7.96 s per loop
# p++ two engines 6 11500
# 1 loop, best of 1: 10.1 s per loop
# p++ two engines 6 12500
# 1 loop, best of 1: 58.3 s per loop
# p++ two engines 6 13500
# 1 loop, best of 1: 19.8 s per loop
# p++ two engines 6 14500
# 1 loop, best of 1: 29.1 s per loop
# p++ two engines 6 15500
# 1 loop, best of 1: 11.9 s per loop
# p++ two engines 6 16500
# 1 loop, best of 1: 10 s per loop
# p++ two engines 6 17500
# 1 loop, best of 1: 9.09 s per loop
# p++ two engines 6 18500
# 1 loop, best of 1: 18.4 s per loop
# p++ two engines 6 19500
# 1 loop, best of 1: 56.6 s per loop
# s++ 7 500
# 1 loop, best of 1: 674 ms per loop
# s++ 7 1500
# 1 loop, best of 1: 1.86 s per loop
# s++ 7 2500
# 1 loop, best of 1: 6.92 s per loop
# s++ 7 3500
# 1 loop, best of 1: 8.62 s per loop
# s++ 7 4500
# 1 loop, best of 1: 1.64 s per loop
# s++ 7 5500
# 1 loop, best of 1: 8.71 s per loop
# s++ 7 6500
# 1 loop, best of 1: 18.5 s per loop
# s++ 7 7500
# 1 loop, best of 1: 21.3 s per loop
# s++ 7 8500
# 1 loop, best of 1: 12.7 s per loop
# s++ 7 9500
# 1 loop, best of 1: 15.9 s per loop
# s++ 7 10500
# 1 loop, best of 1: 20.4 s per loop
# s++ 7 11500
# 1 loop, best of 1: 55.7 s per loop
# s++ 7 12500
# 1 loop, best of 1: 1min 17s per loop
# s++ 7 13500
# 1 loop, best of 1: 35.4 s per loop
# s++ 7 14500
# 1 loop, best of 1: 18.3 s per loop
# s++ 7 15500
# 1 loop, best of 1: 27.5 s per loop
# s++ 7 16500
# 1 loop, best of 1: 35.3 s per loop
# s++ 7 17500
# 1 loop, best of 1: 9.58 s per loop
# s++ 7 18500
# 1 loop, best of 1: 18.1 s per loop
# s++ 7 19500
# 1 loop, best of 1: 24.3 s per loop
# p++ four engines 7 500
# 1 loop, best of 1: 1.71 s per loop
# p++ four engines 7 1500
# 1 loop, best of 1: 2.64 s per loop
# p++ four engines 7 2500
# 1 loop, best of 1: 8.23 s per loop
# p++ four engines 7 3500
# 1 loop, best of 1: 8.47 s per loop
# p++ four engines 7 4500
# 1 loop, best of 1: 2.17 s per loop
# p++ four engines 7 5500
# 1 loop, best of 1: 8.41 s per loop
# p++ four engines 7 6500
# 1 loop, best of 1: 17.2 s per loop
# p++ four engines 7 7500
# 1 loop, best of 1: 19.3 s per loop
# p++ four engines 7 8500
# 1 loop, best of 1: 11.7 s per loop
# p++ four engines 7 9500
# 1 loop, best of 1: 13.9 s per loop
# p++ four engines 7 10500
# 1 loop, best of 1: 18.2 s per loop
# p++ four engines 7 11500
# 1 loop, best of 1: 48.2 s per loop
# p++ four engines 7 12500
# 1 loop, best of 1: 55.7 s per loop
# p++ four engines 7 13500
# 1 loop, best of 1: 21.6 s per loop
# p++ four engines 7 14500
# 1 loop, best of 1: 15.8 s per loop
# p++ four engines 7 15500
# 1 loop, best of 1: 23 s per loop
# p++ four engines 7 16500
# 1 loop, best of 1: 30.1 s per loop
# p++ four engines 7 17500
# 1 loop, best of 1: 9.32 s per loop
# p++ four engines 7 18500
# 1 loop, best of 1: 15.1 s per loop
# p++ four engines 7 19500
# 1 loop, best of 1: 20.5 s per loop
# p++ three engines 7 500
# 1 loop, best of 1: 2.3 s per loop
# p++ three engines 7 1500
# 1 loop, best of 1: 3.09 s per loop
# p++ three engines 7 2500
# 1 loop, best of 1: 9.27 s per loop
# p++ three engines 7 3500
# 1 loop, best of 1: 9.1 s per loop
# p++ three engines 7 4500
# 1 loop, best of 1: 2.46 s per loop
# p++ three engines 7 5500
# 1 loop, best of 1: 7.81 s per loop
# p++ three engines 7 6500
# 1 loop, best of 1: 17.8 s per loop
# p++ three engines 7 7500
# 1 loop, best of 1: 18.6 s per loop
# p++ three engines 7 8500
# 1 loop, best of 1: 11.4 s per loop
# p++ three engines 7 9500
# 1 loop, best of 1: 14.2 s per loop
# p++ three engines 7 10500
# 1 loop, best of 1: 17.6 s per loop
# p++ three engines 7 11500
# 1 loop, best of 1: 47.5 s per loop
# p++ three engines 7 12500
# 1 loop, best of 1: 54 s per loop
# p++ three engines 7 13500
# 1 loop, best of 1: 21.7 s per loop
# p++ three engines 7 14500
# 1 loop, best of 1: 15.7 s per loop
# p++ three engines 7 15500
# 1 loop, best of 1: 21.4 s per loop
# p++ three engines 7 16500
# 1 loop, best of 1: 29.9 s per loop
# p++ three engines 7 17500
# 1 loop, best of 1: 9.12 s per loop
# p++ three engines 7 18500
# 1 loop, best of 1: 14.8 s per loop
# p++ three engines 7 19500
# 1 loop, best of 1: 21.2 s per loop
# p++ two engines 7 500
# 1 loop, best of 1: 2.8 s per loop
# p++ two engines 7 1500
# 1 loop, best of 1: 3.69 s per loop
# p++ two engines 7 2500
# 1 loop, best of 1: 10.2 s per loop
# p++ two engines 7 3500
# got unknown result: 446cc018-6cb13bb6f117ae3653a2df0e
# 1 loop, best of 1: 10.2 s per loop
# p++ two engines 7 4500
# 1 loop, best of 1: 2.67 s per loop
# p++ two engines 7 5500
# 1 loop, best of 1: 8.26 s per loop
# p++ two engines 7 6500
# 1 loop, best of 1: 18.7 s per loop
# p++ two engines 7 7500
# got unknown result: 1720a33e-1b8d9072200b286dc8afd9ab
# 1 loop, best of 1: 20.7 s per loop
# p++ two engines 7 8500
# 1 loop, best of 1: 11.5 s per loop
# p++ two engines 7 9500
# 1 loop, best of 1: 14.6 s per loop
# p++ two engines 7 10500
# 1 loop, best of 1: 19 s per loop
# p++ two engines 7 11500
# 1 loop, best of 1: 48.7 s per loop
# p++ two engines 7 12500
# 1 loop, best of 1: 55.6 s per loop
# p++ two engines 7 13500
# 1 loop, best of 1: 21.5 s per loop
# p++ two engines 7 14500
# 1 loop, best of 1: 15.9 s per loop
# p++ two engines 7 15500
# 1 loop, best of 1: 23.9 s per loop
# p++ two engines 7 16500
# 1 loop, best of 1: 29.5 s per loop
# p++ two engines 7 17500
# 1 loop, best of 1: 8.74 s per loop
# p++ two engines 7 18500
# 1 loop, best of 1: 15.3 s per loop
# p++ two engines 7 19500
# 1 loop, best of 1: 20.7 s per loop
# s++ 8 500
# 1 loop, best of 1: 798 ms per loop
# s++ 8 1500
# 1 loop, best of 1: 1.83 s per loop
# s++ 8 2500
# 1 loop, best of 1: 3.37 s per loop
# s++ 8 3500
# 1 loop, best of 1: 1.95 s per loop
# s++ 8 4500
# 1 loop, best of 1: 3.79 s per loop
# s++ 8 5500
# 1 loop, best of 1: 3.97 s per loop
# s++ 8 6500
# 1 loop, best of 1: 6.95 s per loop
# s++ 8 7500
# 1 loop, best of 1: 9.63 s per loop
# s++ 8 8500
# 1 loop, best of 1: 11.5 s per loop
# s++ 8 9500
# 1 loop, best of 1: 26.2 s per loop
# s++ 8 10500
# 1 loop, best of 1: 23.2 s per loop
# s++ 8 11500
# 1 loop, best of 1: 7.91 s per loop
# s++ 8 12500
# 1 loop, best of 1: 30.7 s per loop
# s++ 8 13500
# 1 loop, best of 1: 23.5 s per loop
# s++ 8 14500
# 1 loop, best of 1: 1min 5s per loop
# s++ 8 15500
# 1 loop, best of 1: 12 s per loop
# s++ 8 16500
# 1 loop, best of 1: 8.01 s per loop
# s++ 8 17500
# 1 loop, best of 1: 13 s per loop
# s++ 8 18500
# 1 loop, best of 1: 14.4 s per loop
# s++ 8 19500
# 1 loop, best of 1: 11.3 s per loop
# p++ four engines 8 500
# 1 loop, best of 1: 1.33 s per loop
# p++ four engines 8 1500
# 1 loop, best of 1: 2.49 s per loop
# p++ four engines 8 2500
# 1 loop, best of 1: 4.27 s per loop
# p++ four engines 8 3500
# 1 loop, best of 1: 2.72 s per loop
# p++ four engines 8 4500
# 1 loop, best of 1: 3.88 s per loop
# p++ four engines 8 5500
# 1 loop, best of 1: 3.7 s per loop
# p++ four engines 8 6500
# 1 loop, best of 1: 7.1 s per loop
# p++ four engines 8 7500
# 1 loop, best of 1: 8.5 s per loop
# p++ four engines 8 8500
# 1 loop, best of 1: 13.8 s per loop
# p++ four engines 8 9500
# 1 loop, best of 1: 20.4 s per loop
# p++ four engines 8 10500
# 1 loop, best of 1: 18.4 s per loop
# p++ four engines 8 11500
# 1 loop, best of 1: 6.79 s per loop
# p++ four engines 8 12500
# 1 loop, best of 1: 23.1 s per loop
# p++ four engines 8 13500
# 1 loop, best of 1: 18.6 s per loop
# p++ four engines 8 14500
# 1 loop, best of 1: 48.9 s per loop
# p++ four engines 8 15500
# 1 loop, best of 1: 9.55 s per loop
# p++ four engines 8 16500
# 1 loop, best of 1: 6.81 s per loop
# p++ four engines 8 17500
# 1 loop, best of 1: 10.6 s per loop
# p++ four engines 8 18500
# 1 loop, best of 1: 11.7 s per loop
# p++ four engines 8 19500
# 1 loop, best of 1: 9.37 s per loop
# p++ three engines 8 500
# 1 loop, best of 1: 2.03 s per loop
# p++ three engines 8 1500
# 1 loop, best of 1: 2.72 s per loop
# p++ three engines 8 2500
# 1 loop, best of 1: 4.3 s per loop
# p++ three engines 8 3500
# 1 loop, best of 1: 2.5 s per loop
# p++ three engines 8 4500
# 1 loop, best of 1: 4.37 s per loop
# p++ three engines 8 5500
# 1 loop, best of 1: 4.4 s per loop
# p++ three engines 8 6500
# 1 loop, best of 1: 6.52 s per loop
# p++ three engines 8 7500
# 1 loop, best of 1: 9.44 s per loop
# p++ three engines 8 8500
# 1 loop, best of 1: 10.1 s per loop
# p++ three engines 8 9500
# 1 loop, best of 1: 23.7 s per loop
# p++ three engines 8 10500
# 1 loop, best of 1: 20.3 s per loop
# p++ three engines 8 11500
# 1 loop, best of 1: 7.46 s per loop
# p++ three engines 8 12500
# 1 loop, best of 1: 25.4 s per loop
# p++ three engines 8 13500
# 1 loop, best of 1: 20 s per loop
# p++ three engines 8 14500
# 1 loop, best of 1: 53.6 s per loop
# p++ three engines 8 15500
# 1 loop, best of 1: 9.95 s per loop
# p++ three engines 8 16500
# 1 loop, best of 1: 7.5 s per loop
# p++ three engines 8 17500
# 1 loop, best of 1: 11.8 s per loop
# p++ three engines 8 18500
# 1 loop, best of 1: 11.4 s per loop
# p++ three engines 8 19500
# 1 loop, best of 1: 10.2 s per loop
# p++ two engines 8 500
# 1 loop, best of 1: 2.22 s per loop
# p++ two engines 8 1500
# 1 loop, best of 1: 3.18 s per loop
# p++ two engines 8 2500
# 1 loop, best of 1: 5.32 s per loop
# p++ two engines 8 3500
# 1 loop, best of 1: 2.93 s per loop
# p++ two engines 8 4500
# 1 loop, best of 1: 4.38 s per loop
# p++ two engines 8 5500
# 1 loop, best of 1: 3.94 s per loop
# p++ two engines 8 6500
# 1 loop, best of 1: 7.77 s per loop
# p++ two engines 8 7500
# 1 loop, best of 1: 9.02 s per loop
# p++ two engines 8 8500
# 1 loop, best of 1: 11.3 s per loop
# p++ two engines 8 9500
# 1 loop, best of 1: 24.1 s per loop
# p++ two engines 8 10500
# 1 loop, best of 1: 21.3 s per loop
# p++ two engines 8 11500
# 1 loop, best of 1: 7.01 s per loop
# p++ two engines 8 12500
# 1 loop, best of 1: 27.2 s per loop
# p++ two engines 8 13500
# 1 loop, best of 1: 20.3 s per loop
# p++ two engines 8 14500
# 1 loop, best of 1: 55.4 s per loop
# p++ two engines 8 15500
# 1 loop, best of 1: 10.4 s per loop
# p++ two engines 8 16500
# 1 loop, best of 1: 7.4 s per loop
# p++ two engines 8 17500
# 1 loop, best of 1: 12.2 s per loop
# p++ two engines 8 18500
# 1 loop, best of 1: 12.3 s per loop
# p++ two engines 8 19500
# 1 loop, best of 1: 10 s per loop
# s++ 9 500
# 1 loop, best of 1: 497 ms per loop
# s++ 9 1500
# 1 loop, best of 1: 2.14 s per loop
# s++ 9 2500
# 1 loop, best of 1: 5 s per loop
# s++ 9 3500
# 1 loop, best of 1: 9.64 s per loop
# s++ 9 4500
# 1 loop, best of 1: 13.6 s per loop
# s++ 9 5500
# 1 loop, best of 1: 2.5 s per loop
# s++ 9 6500
# 1 loop, best of 1: 13.1 s per loop
# s++ 9 7500
# 1 loop, best of 1: 26.4 s per loop
# s++ 9 8500
# 1 loop, best of 1: 12.1 s per loop
# s++ 9 9500
# 1 loop, best of 1: 21.6 s per loop
# s++ 9 10500
# 1 loop, best of 1: 1min 4s per loop
# s++ 9 11500
# 1 loop, best of 1: 5.21 s per loop
# s++ 9 12500
# 1 loop, best of 1: 34.2 s per loop
# s++ 9 13500
# 1 loop, best of 1: 15.9 s per loop
# s++ 9 14500
# 1 loop, best of 1: 49.3 s per loop
# s++ 9 15500
# 1 loop, best of 1: 1min 54s per loop
# s++ 9 16500
# 1 loop, best of 1: 7.44 s per loop
# s++ 9 17500
# 1 loop, best of 1: 47.9 s per loop
# s++ 9 18500
# 1 loop, best of 1: 30.8 s per loop
# s++ 9 19500
# 1 loop, best of 1: 42.1 s per loop
# p++ four engines 9 500
# 1 loop, best of 1: 1.2 s per loop
# p++ four engines 9 1500
# 1 loop, best of 1: 3.05 s per loop
# p++ four engines 9 2500
# 1 loop, best of 1: 5.02 s per loop
# p++ four engines 9 3500
# 1 loop, best of 1: 11.1 s per loop
# p++ four engines 9 4500
# 1 loop, best of 1: 13.5 s per loop
# p++ four engines 9 5500
# 1 loop, best of 1: 2.61 s per loop
# p++ four engines 9 6500
# 1 loop, best of 1: 12.3 s per loop
# p++ four engines 9 7500
# 1 loop, best of 1: 23.4 s per loop
# p++ four engines 9 8500
# 1 loop, best of 1: 11.8 s per loop
# p++ four engines 9 9500
# 1 loop, best of 1: 18.9 s per loop
# p++ four engines 9 10500
# 1 loop, best of 1: 56.1 s per loop
# p++ four engines 9 11500
# 1 loop, best of 1: 5.34 s per loop
# p++ four engines 9 12500
# 1 loop, best of 1: 29.9 s per loop
# p++ four engines 9 13500
# 1 loop, best of 1: 14 s per loop
# p++ four engines 9 14500
# 1 loop, best of 1: 42.3 s per loop
# p++ four engines 9 15500
# 1 loop, best of 1: 1min 19s per loop
# p++ four engines 9 16500
# 1 loop, best of 1: 7.71 s per loop
# p++ four engines 9 17500
# 1 loop, best of 1: 40.2 s per loop
# p++ four engines 9 18500
# 1 loop, best of 1: 26.5 s per loop
# p++ four engines 9 19500
# 1 loop, best of 1: 35.2 s per loop
# p++ three engines 9 500
# 1 loop, best of 1: 1.66 s per loop
# p++ three engines 9 1500
# 1 loop, best of 1: 3.5 s per loop
# p++ three engines 9 2500
# 1 loop, best of 1: 6.32 s per loop
# p++ three engines 9 3500
# 1 loop, best of 1: 10.8 s per loop
# p++ three engines 9 4500
# 1 loop, best of 1: 13.9 s per loop
# p++ three engines 9 5500
# 1 loop, best of 1: 3.07 s per loop
# p++ three engines 9 6500
# 1 loop, best of 1: 12.1 s per loop
# p++ three engines 9 7500
# 1 loop, best of 1: 24.3 s per loop
# p++ three engines 9 8500
# 1 loop, best of 1: 11.4 s per loop
# p++ three engines 9 9500
# 1 loop, best of 1: 19.5 s per loop
# p++ three engines 9 10500
# 1 loop, best of 1: 55.4 s per loop
# p++ three engines 9 11500
# 1 loop, best of 1: 5.34 s per loop
# p++ three engines 9 12500
# 1 loop, best of 1: 28.7 s per loop
# p++ three engines 9 13500
# 1 loop, best of 1: 13.8 s per loop
# p++ three engines 9 14500
# 1 loop, best of 1: 42.2 s per loop
# p++ three engines 9 15500
# 1 loop, best of 1: 1min 15s per loop
# p++ three engines 9 16500
# 1 loop, best of 1: 7.06 s per loop
# p++ three engines 9 17500
# 1 loop, best of 1: 38.4 s per loop
# p++ three engines 9 18500
# 1 loop, best of 1: 25.3 s per loop
# p++ three engines 9 19500
# 1 loop, best of 1: 33.9 s per loop
# p++ two engines 9 500
# 1 loop, best of 1: 1.99 s per loop
# p++ two engines 9 1500
# 1 loop, best of 1: 4.22 s per loop
# p++ two engines 9 2500
# 1 loop, best of 1: 6.8 s per loop
# p++ two engines 9 3500
# 1 loop, best of 1: 12.4 s per loop
# p++ two engines 9 4500
# 1 loop, best of 1: 15 s per loop
# p++ two engines 9 5500
# 1 loop, best of 1: 3.22 s per loop
# p++ two engines 9 6500
# 1 loop, best of 1: 12.5 s per loop
# p++ two engines 9 7500
# 1 loop, best of 1: 24.6 s per loop
# p++ two engines 9 8500
# 1 loop, best of 1: 12.4 s per loop
# p++ two engines 9 9500
# 1 loop, best of 1: 19.4 s per loop
# p++ two engines 9 10500
# 1 loop, best of 1: 58.3 s per loop
# p++ two engines 9 11500
# 1 loop, best of 1: 5.06 s per loop
# p++ two engines 9 12500
# 1 loop, best of 1: 30.2 s per loop
# p++ two engines 9 13500
# 1 loop, best of 1: 14 s per loop
# p++ two engines 9 14500
# 1 loop, best of 1: 42.9 s per loop
# p++ two engines 9 15500
# 1 loop, best of 1: 1min 18s per loop
# p++ two engines 9 16500
# 1 loop, best of 1: 7.46 s per loop
# p++ two engines 9 17500
# 1 loop, best of 1: 39 s per loop
# p++ two engines 9 18500
# 1 loop, best of 1: 26.1 s per loop
# p++ two engines 9 19500
# 1 loop, best of 1: 34.6 s per loop
# s++ 10 500
# 1 loop, best of 1: 466 ms per loop
# s++ 10 1500
# 1 loop, best of 1: 887 ms per loop
# s++ 10 2500
# 1 loop, best of 1: 6.31 s per loop
# s++ 10 3500
# 1 loop, best of 1: 2.63 s per loop
# s++ 10 4500
# 1 loop, best of 1: 3.38 s per loop
# s++ 10 5500
# 1 loop, best of 1: 3.64 s per loop
# s++ 10 6500
# 1 loop, best of 1: 12.4 s per loop
# s++ 10 7500
# 1 loop, best of 1: 8.26 s per loop
# s++ 10 8500
# 1 loop, best of 1: 9.55 s per loop
# s++ 10 9500
# 1 loop, best of 1: 47.7 s per loop
# s++ 10 10500
# 1 loop, best of 1: 8.4 s per loop
# s++ 10 11500
# 1 loop, best of 1: 48 s per loop
# s++ 10 12500
# 1 loop, best of 1: 17.5 s per loop
# s++ 10 13500
# 1 loop, best of 1: 57.1 s per loop
# s++ 10 14500
# 1 loop, best of 1: 1min per loop
# s++ 10 15500
# 1 loop, best of 1: 35.3 s per loop
# s++ 10 16500
# 1 loop, best of 1: 34.5 s per loop
# s++ 10 17500
# 1 loop, best of 1: 20.4 s per loop
# s++ 10 18500
# 1 loop, best of 1: 1min 9s per loop
# s++ 10 19500
# 1 loop, best of 1: 23.5 s per loop
# p++ four engines 10 500
# 1 loop, best of 1: 1.22 s per loop
# p++ four engines 10 1500
# 1 loop, best of 1: 1.37 s per loop
# p++ four engines 10 2500
# 1 loop, best of 1: 7.02 s per loop
# p++ four engines 10 3500
# 1 loop, best of 1: 3.1 s per loop
# p++ four engines 10 4500
# 1 loop, best of 1: 4.61 s per loop
# p++ four engines 10 5500
# 1 loop, best of 1: 3.68 s per loop
# p++ four engines 10 6500
# 1 loop, best of 1: 12.8 s per loop
# p++ four engines 10 7500
# 1 loop, best of 1: 7.76 s per loop
# p++ four engines 10 8500
# 1 loop, best of 1: 10.6 s per loop
# p++ four engines 10 9500
# 1 loop, best of 1: 44.5 s per loop
# p++ four engines 10 10500
# 1 loop, best of 1: 6.96 s per loop
# p++ four engines 10 11500
# 1 loop, best of 1: 41.7 s per loop
# p++ four engines 10 12500
# 1 loop, best of 1: 15.9 s per loop
# p++ four engines 10 13500
# 1 loop, best of 1: 54.2 s per loop
# p++ four engines 10 14500
# 1 loop, best of 1: 59.5 s per loop
# p++ four engines 10 15500
# 1 loop, best of 1: 31.4 s per loop
# p++ four engines 10 16500
# 1 loop, best of 1: 20.5 s per loop
# p++ four engines 10 17500
# 1 loop, best of 1: 16 s per loop
# p++ four engines 10 18500
# 1 loop, best of 1: 52.4 s per loop
# p++ four engines 10 19500
# 1 loop, best of 1: 16 s per loop
# p++ three engines 10 500
# 1 loop, best of 1: 1.48 s per loop
# p++ three engines 10 1500
# 1 loop, best of 1: 1.57 s per loop
# p++ three engines 10 2500
# 1 loop, best of 1: 7.71 s per loop
# p++ three engines 10 3500
# 1 loop, best of 1: 3.08 s per loop
# p++ three engines 10 4500
# 1 loop, best of 1: 3.48 s per loop
# p++ three engines 10 5500
# 1 loop, best of 1: 4.56 s per loop
# p++ three engines 10 6500
# 1 loop, best of 1: 10.9 s per loop
# p++ three engines 10 7500
# 1 loop, best of 1: 8.22 s per loop
# p++ three engines 10 8500
# 1 loop, best of 1: 8.5 s per loop
# p++ three engines 10 9500
# 1 loop, best of 1: 40.2 s per loop
# p++ three engines 10 10500
# 1 loop, best of 1: 6.27 s per loop
# p++ three engines 10 11500
# 1 loop, best of 1: 36.6 s per loop
# p++ three engines 10 12500
# 1 loop, best of 1: 13.3 s per loop
# p++ three engines 10 13500
# 1 loop, best of 1: 42.8 s per loop
# p++ three engines 10 14500
# 1 loop, best of 1: 44.3 s per loop
# p++ three engines 10 15500
# 1 loop, best of 1: 26 s per loop
# p++ three engines 10 16500
# 1 loop, best of 1: 20.5 s per loop
# p++ three engines 10 17500
# 1 loop, best of 1: 15.6 s per loop
# p++ three engines 10 18500
# 1 loop, best of 1: 50.8 s per loop
# p++ three engines 10 19500
# 1 loop, best of 1: 15.4 s per loop
# p++ two engines 10 500
# 1 loop, best of 1: 1.78 s per loop
# p++ two engines 10 1500
# 1 loop, best of 1: 1.72 s per loop
# p++ two engines 10 2500
# 1 loop, best of 1: 8.15 s per loop
# p++ two engines 10 3500
# 1 loop, best of 1: 3.79 s per loop
# p++ two engines 10 4500
# 1 loop, best of 1: 3.98 s per loop
# p++ two engines 10 5500
# 1 loop, best of 1: 4.1 s per loop
# p++ two engines 10 6500
# 1 loop, best of 1: 12.5 s per loop
# p++ two engines 10 7500
# 1 loop, best of 1: 8.12 s per loop
# p++ two engines 10 8500
# 1 loop, best of 1: 9.33 s per loop
# p++ two engines 10 9500
# 1 loop, best of 1: 41.4 s per loop
# p++ two engines 10 10500
# 1 loop, best of 1: 6.25 s per loop
# p++ two engines 10 11500
# 1 loop, best of 1: 36.6 s per loop
# p++ two engines 10 12500
# 1 loop, best of 1: 14 s per loop
# p++ two engines 10 13500
# 1 loop, best of 1: 44.3 s per loop
# p++ two engines 10 14500
# 1 loop, best of 1: 45.2 s per loop
# p++ two engines 10 15500
# 1 loop, best of 1: 27.2 s per loop
# p++ two engines 10 16500
# 1 loop, best of 1: 20.2 s per loop
# p++ two engines 10 17500
# 1 loop, best of 1: 16.1 s per loop
# p++ two engines 10 18500
# 1 loop, best of 1: 51.5 s per loop
# p++ two engines 10 19500
# 1 loop, best of 1: 16.2 s per loop
# s++ 11 500
# 1 loop, best of 1: 488 ms per loop
# s++ 11 1500
# 1 loop, best of 1: 2.02 s per loop
# s++ 11 2500
# 1 loop, best of 1: 5.58 s per loop
# s++ 11 3500
# 1 loop, best of 1: 3.98 s per loop
# s++ 11 4500
# 1 loop, best of 1: 13.3 s per loop
# s++ 11 5500
# 1 loop, best of 1: 10.5 s per loop
# s++ 11 6500
# 1 loop, best of 1: 9.08 s per loop
# s++ 11 7500
# 1 loop, best of 1: 5.63 s per loop
# s++ 11 8500
# 1 loop, best of 1: 23.6 s per loop
# s++ 11 9500
# 1 loop, best of 1: 7.08 s per loop
# s++ 11 10500
# 1 loop, best of 1: 8.99 s per loop
# s++ 11 11500
# 1 loop, best of 1: 47.4 s per loop
# s++ 11 12500
# 1 loop, best of 1: 12.2 s per loop
# s++ 11 13500
# 1 loop, best of 1: 39.3 s per loop
# s++ 11 14500
# 1 loop, best of 1: 9.91 s per loop
# s++ 11 15500
# 1 loop, best of 1: 23.8 s per loop
# s++ 11 16500
# 1 loop, best of 1: 1min 11s per loop
# s++ 11 17500
# 1 loop, best of 1: 1min 3s per loop
# s++ 11 18500
# 1 loop, best of 1: 19.7 s per loop
# s++ 11 19500
# 1 loop, best of 1: 13.2 s per loop
# p++ four engines 11 500
# 1 loop, best of 1: 1.2 s per loop
# p++ four engines 11 1500
# 1 loop, best of 1: 2.79 s per loop
# p++ four engines 11 2500
# 1 loop, best of 1: 6.43 s per loop
# p++ four engines 11 3500
# 1 loop, best of 1: 4.34 s per loop
# p++ four engines 11 4500
# 1 loop, best of 1: 11.7 s per loop
# p++ four engines 11 5500
# 1 loop, best of 1: 9.56 s per loop
# p++ four engines 11 6500
# 1 loop, best of 1: 7.38 s per loop
# p++ four engines 11 7500
# 1 loop, best of 1: 5.49 s per loop
# p++ four engines 11 8500
# 1 loop, best of 1: 18.6 s per loop
# p++ four engines 11 9500
# 1 loop, best of 1: 5.94 s per loop
# p++ four engines 11 10500
# 1 loop, best of 1: 5.55 s per loop
# p++ four engines 11 11500
# 1 loop, best of 1: 31 s per loop
# p++ four engines 11 12500
# 1 loop, best of 1: 9.55 s per loop
# p++ four engines 11 13500
# 1 loop, best of 1: 30.1 s per loop
# p++ four engines 11 14500
# 1 loop, best of 1: 8.09 s per loop
# p++ four engines 11 15500
# 1 loop, best of 1: 19.3 s per loop
# p++ four engines 11 16500
# 1 loop, best of 1: 52.6 s per loop
# p++ four engines 11 17500
# 1 loop, best of 1: 46.7 s per loop
# p++ four engines 11 18500
# 1 loop, best of 1: 15.3 s per loop
# p++ four engines 11 19500
# 1 loop, best of 1: 10.7 s per loop
# p++ three engines 11 500
# 1 loop, best of 1: 1.66 s per loop
# p++ three engines 11 1500
# 1 loop, best of 1: 3.34 s per loop
# p++ three engines 11 2500
# 1 loop, best of 1: 5.82 s per loop
# p++ three engines 11 3500
# 1 loop, best of 1: 5.01 s per loop
# p++ three engines 11 4500
# 1 loop, best of 1: 13.7 s per loop
# p++ three engines 11 5500
# 1 loop, best of 1: 11.3 s per loop
# p++ three engines 11 6500
# 1 loop, best of 1: 8.92 s per loop
# p++ three engines 11 7500
# 1 loop, best of 1: 5.36 s per loop
# p++ three engines 11 8500
# got unknown result: e7c74c55-7b51bb912cb7966043746da7
# 1 loop, best of 1: 20.9 s per loop
# p++ three engines 11 9500
# 1 loop, best of 1: 7.33 s per loop
# p++ three engines 11 10500
# 1 loop, best of 1: 5.37 s per loop
# p++ three engines 11 11500
# ...
# p++ three engines 37 2500
# 1 loop, best of 1: 2.23 s per loop
# p++ three engines 37 3500
# 1 loop, best of 1: 8.67 s per loop
# p++ three engines 37 4500
# 1 loop, best of 1: 5.87 s per loop
# p++ three engines 37 5500
# 1 loop, best of 1: 5.49 s per loop
# p++ three engines 37 6500
# 1 loop, best of 1: 12.6 s per loop
# p++ three engines 37 7500
# 1 loop, best of 1: 25.7 s per loop
# p++ three engines 37 8500
# 1 loop, best of 1: 7.95 s per loop
# p++ three engines 37 9500
# 1 loop, best of 1: 1min 9s per loop
# p++ three engines 37 10500
# 1 loop, best of 1: 36 s per loop
# p++ three engines 37 11500
# 1 loop, best of 1: 21.6 s per loop
# p++ three engines 37 12500
# 1 loop, best of 1: 56.3 s per loop
# p++ three engines 37 13500
# 1 loop, best of 1: 16.3 s per loop
# p++ three engines 37 14500
# 1 loop, best of 1: 10.3 s per loop
# p++ three engines 37 15500
# 1 loop, best of 1: 12.6 s per loop
# p++ three engines 37 16500
# 1 loop, best of 1: 16.1 s per loop
# p++ three engines 37 17500
# 1 loop, best of 1: 39.6 s per loop
# p++ three engines 37 18500
# 1 loop, best of 1: 25.4 s per loop
# p++ three engines 37 19500
# 1 loop, best of 1: 8.01 s per loop
# p++ two engines 37 500
# 1 loop, best of 1: 1.77 s per loop
# p++ two engines 37 1500
# 1 loop, best of 1: 2.71 s per loop
# p++ two engines 37 2500
# 1 loop, best of 1: 2.72 s per loop
# p++ two engines 37 3500
# 1 loop, best of 1: 9.08 s per loop
# p++ two engines 37 4500
# 1 loop, best of 1: 6.38 s per loop
# p++ two engines 37 5500
# 1 loop, best of 1: 5.6 s per loop
# p++ two engines 37 6500
# 1 loop, best of 1: 13.6 s per loop
# p++ two engines 37 7500
# 1 loop, best of 1: 26 s per loop
# p++ two engines 37 8500
# 1 loop, best of 1: 8.61 s per loop
# p++ two engines 37 9500
# 1 loop, best of 1: 1min 12s per loop
# p++ two engines 37 10500
# 1 loop, best of 1: 37.5 s per loop
# p++ two engines 37 11500
# 1 loop, best of 1: 21.9 s per loop
# p++ two engines 37 12500
# 1 loop, best of 1: 59.6 s per loop
# p++ two engines 37 13500
# 1 loop, best of 1: 16.6 s per loop
# p++ two engines 37 14500
# 1 loop, best of 1: 9.69 s per loop
# p++ two engines 37 15500
# 1 loop, best of 1: 13.2 s per loop
# p++ two engines 37 16500
# 1 loop, best of 1: 16.5 s per loop
# p++ two engines 37 17500
# 1 loop, best of 1: 40.8 s per loop
# p++ two engines 37 18500
# 1 loop, best of 1: 26.1 s per loop
# p++ two engines 37 19500
# 1 loop, best of 1: 8.51 s per loop
# s++ 38 500
# 1 loop, best of 1: 349 ms per loop
# s++ 38 1500
# 1 loop, best of 1: 2.02 s per loop
# s++ 38 2500
# 1 loop, best of 1: 1.65 s per loop
# s++ 38 3500
# 1 loop, best of 1: 6.44 s per loop
# s++ 38 4500
# 1 loop, best of 1: 5.1 s per loop
# s++ 38 5500
# 1 loop, best of 1: 2.54 s per loop
# s++ 38 6500
# 1 loop, best of 1: 5.52 s per loop
# s++ 38 7500
# 1 loop, best of 1: 10.7 s per loop
# s++ 38 8500
# 1 loop, best of 1: 5.16 s per loop
# s++ 38 9500
# 1 loop, best of 1: 20.2 s per loop
# s++ 38 10500
# 1 loop, best of 1: 24.5 s per loop
# s++ 38 11500
# 1 loop, best of 1: 13.6 s per loop
# s++ 38 12500
# 1 loop, best of 1: 56.9 s per loop
# s++ 38 13500
# 1 loop, best of 1: 11.4 s per loop
# s++ 38 14500
# 1 loop, best of 1: 44 s per loop
# s++ 38 15500
# 1 loop, best of 1: 7.6 s per loop
# s++ 38 16500
# 1 loop, best of 1: 12.3 s per loop
# s++ 38 17500
# 1 loop, best of 1: 9.95 s per loop
# s++ 38 18500
# 1 loop, best of 1: 16 s per loop
# s++ 38 19500
# 1 loop, best of 1: 11.2 s per loop
# p++ four engines 38 500
# 1 loop, best of 1: 866 ms per loop
# p++ four engines 38 1500
# 1 loop, best of 1: 2.83 s per loop
# p++ four engines 38 2500
# 1 loop, best of 1: 1.99 s per loop
# p++ four engines 38 3500
# 1 loop, best of 1: 6.45 s per loop
# p++ four engines 38 4500
# 1 loop, best of 1: 5.51 s per loop
# p++ four engines 38 5500
# 1 loop, best of 1: 2.48 s per loop
# p++ four engines 38 6500
# 1 loop, best of 1: 4.75 s per loop
# p++ four engines 38 7500
# 1 loop, best of 1: 10.6 s per loop
# p++ four engines 38 8500
# 1 loop, best of 1: 4.49 s per loop
# p++ four engines 38 9500
# 1 loop, best of 1: 18.5 s per loop
# p++ four engines 38 10500
# 1 loop, best of 1: 22.4 s per loop
# p++ four engines 38 11500
# 1 loop, best of 1: 11.7 s per loop
# p++ four engines 38 12500
# 1 loop, best of 1: 48.7 s per loop
# p++ four engines 38 13500
# 1 loop, best of 1: 9.7 s per loop
# p++ four engines 38 14500
# 1 loop, best of 1: 38.5 s per loop
# p++ four engines 38 15500
# 1 loop, best of 1: 6.53 s per loop
# p++ four engines 38 16500
# 1 loop, best of 1: 11.5 s per loop
# p++ four engines 38 17500
# 1 loop, best of 1: 8.48 s per loop
# p++ four engines 38 18500
# 1 loop, best of 1: 14.2 s per loop
# p++ four engines 38 19500
# 1 loop, best of 1: 10.3 s per loop
# p++ three engines 38 500
# 1 loop, best of 1: 1.17 s per loop
# p++ three engines 38 1500
# 1 loop, best of 1: 3.36 s per loop
# p++ three engines 38 2500
# 1 loop, best of 1: 2.2 s per loop
# p++ three engines 38 3500
# 1 loop, best of 1: 7.2 s per loop
# p++ three engines 38 4500
# 1 loop, best of 1: 5.35 s per loop
# p++ three engines 38 5500
# 1 loop, best of 1: 2.73 s per loop
# p++ three engines 38 6500
# 1 loop, best of 1: 5.07 s per loop
# p++ three engines 38 7500
# 1 loop, best of 1: 10.3 s per loop
# p++ three engines 38 8500
# 1 loop, best of 1: 4.58 s per loop
# p++ three engines 38 9500
# 1 loop, best of 1: 19 s per loop
# p++ three engines 38 10500
# 1 loop, best of 1: 21.2 s per loop
# p++ three engines 38 11500
# 1 loop, best of 1: 12.2 s per loop
# p++ three engines 38 12500
# 1 loop, best of 1: 47.3 s per loop
# p++ three engines 38 13500
# 1 loop, best of 1: 9.69 s per loop
# p++ three engines 38 14500
# 1 loop, best of 1: 37.2 s per loop
# p++ three engines 38 15500
# 1 loop, best of 1: 6.58 s per loop
# p++ three engines 38 16500
# 1 loop, best of 1: 11.5 s per loop
# p++ three engines 38 17500
# 1 loop, best of 1: 8.53 s per loop
# p++ three engines 38 18500
# 1 loop, best of 1: 13.6 s per loop
# p++ three engines 38 19500
# 1 loop, best of 1: 10 s per loop
# p++ two engines 38 500
# 1 loop, best of 1: 1.43 s per loop
# p++ two engines 38 1500
# 1 loop, best of 1: 3.78 s per loop
# p++ two engines 38 2500
# 1 loop, best of 1: 2.43 s per loop
# p++ two engines 38 3500
# 1 loop, best of 1: 7.35 s per loop
# p++ two engines 38 4500
# 1 loop, best of 1: 5.99 s per loop
# p++ two engines 38 5500
# 1 loop, best of 1: 2.89 s per loop
# p++ two engines 38 6500
# 1 loop, best of 1: 5.6 s per loop
# p++ two engines 38 7500
# 1 loop, best of 1: 10.8 s per loop
# p++ two engines 38 8500
# 1 loop, best of 1: 5.23 s per loop
# p++ two engines 38 9500
# 1 loop, best of 1: 19.1 s per loop
# p++ two engines 38 10500
# 1 loop, best of 1: 21.7 s per loop
# p++ two engines 38 11500
# 1 loop, best of 1: 12.5 s per loop
# p++ two engines 38 12500
# 1 loop, best of 1: 49 s per loop
# p++ two engines 38 13500
# 1 loop, best of 1: 11 s per loop
# p++ two engines 38 14500
# 1 loop, best of 1: 37.4 s per loop
# p++ two engines 38 15500
# 1 loop, best of 1: 6.52 s per loop
# p++ two engines 38 16500
# 1 loop, best of 1: 11.2 s per loop
# p++ two engines 38 17500
# 1 loop, best of 1: 9.37 s per loop
# p++ two engines 38 18500
# 1 loop, best of 1: 13.6 s per loop
# p++ two engines 38 19500
# 1 loop, best of 1: 10.1 s per loop
# s++ 39 500
# 1 loop, best of 1: 601 ms per loop
# s++ 39 1500
# 1 loop, best of 1: 1.57 s per loop
# s++ 39 2500
# 1 loop, best of 1: 2.55 s per loop
# s++ 39 3500
# 1 loop, best of 1: 5.59 s per loop
# s++ 39 4500
# 1 loop, best of 1: 3.42 s per loop
# s++ 39 5500
# 1 loop, best of 1: 3.64 s per loop
# s++ 39 6500
# 1 loop, best of 1: 10.2 s per loop
# s++ 39 7500
# 1 loop, best of 1: 23.6 s per loop
# s++ 39 8500
# 1 loop, best of 1: 6.88 s per loop
# s++ 39 9500
# 1 loop, best of 1: 13.2 s per loop
# s++ 39 10500
# 1 loop, best of 1: 21.5 s per loop
# s++ 39 11500
# 1 loop, best of 1: 36.1 s per loop
# s++ 39 12500
# 1 loop, best of 1: 7.58 s per loop
# s++ 39 13500
# 1 loop, best of 1: 48.2 s per loop
# s++ 39 14500
# 1 loop, best of 1: 10.8 s per loop
# s++ 39 15500
# 1 loop, best of 1: 7.53 s per loop
# s++ 39 16500
# 1 loop, best of 1: 35.4 s per loop
# s++ 39 17500
# 1 loop, best of 1: 35.8 s per loop
# s++ 39 18500
# 1 loop, best of 1: 1min 47s per loop
# s++ 39 19500
# 1 loop, best of 1: 55.8 s per loop
# p++ four engines 39 500
# 1 loop, best of 1: 1.46 s per loop
# p++ four engines 39 1500
# 1 loop, best of 1: 2.29 s per loop
# p++ four engines 39 2500
# 1 loop, best of 1: 2.3 s per loop
# p++ four engines 39 3500
# 1 loop, best of 1: 5.66 s per loop
# p++ four engines 39 4500
# 1 loop, best of 1: 4.17 s per loop
# p++ four engines 39 5500
# 1 loop, best of 1: 3.8 s per loop
# p++ four engines 39 6500
# 1 loop, best of 1: 8.59 s per loop
# p++ four engines 39 7500
# 1 loop, best of 1: 22.3 s per loop
# p++ four engines 39 8500
# 1 loop, best of 1: 5.87 s per loop
# p++ four engines 39 9500
# 1 loop, best of 1: 12 s per loop
# p++ four engines 39 10500
# 1 loop, best of 1: 19.2 s per loop
# p++ four engines 39 11500
# 1 loop, best of 1: 31.8 s per loop
# p++ four engines 39 12500
# 1 loop, best of 1: 6.51 s per loop
# p++ four engines 39 13500
# 1 loop, best of 1: 40.9 s per loop
# p++ four engines 39 14500
# 1 loop, best of 1: 10.2 s per loop
# p++ four engines 39 15500
# 1 loop, best of 1: 6.23 s per loop
# p++ four engines 39 16500
# 1 loop, best of 1: 30.6 s per loop
# p++ four engines 39 17500
# 1 loop, best of 1: 30.7 s per loop
# p++ four engines 39 18500
# 1 loop, best of 1: 1min 29s per loop
# p++ four engines 39 19500
# 1 loop, best of 1: 45.9 s per loop
# p++ three engines 39 500
# 1 loop, best of 1: 2.09 s per loop
# p++ three engines 39 1500
# 1 loop, best of 1: 3.18 s per loop
# p++ three engines 39 2500
# 1 loop, best of 1: 2.58 s per loop
# p++ three engines 39 3500
# 1 loop, best of 1: 6.04 s per loop
# p++ three engines 39 4500
# 1 loop, best of 1: 3.74 s per loop
# p++ three engines 39 5500
# 1 loop, best of 1: 4.38 s per loop
# p++ three engines 39 6500
# 1 loop, best of 1: 8.7 s per loop
# p++ three engines 39 7500
# 1 loop, best of 1: 21.9 s per loop
# p++ three engines 39 8500
# 1 loop, best of 1: 5.98 s per loop
# p++ three engines 39 9500
# 1 loop, best of 1: 12.2 s per loop
# p++ three engines 39 10500
# 1 loop, best of 1: 19 s per loop
# p++ three engines 39 11500
# 1 loop, best of 1: 31.2 s per loop
# p++ three engines 39 12500
# 1 loop, best of 1: 6.23 s per loop
# p++ three engines 39 13500
# 1 loop, best of 1: 40.2 s per loop
# p++ three engines 39 14500
# 1 loop, best of 1: 8.94 s per loop
# p++ three engines 39 15500
# 1 loop, best of 1: 7.18 s per loop
# p++ three engines 39 16500
# 1 loop, best of 1: 29.7 s per loop
# p++ three engines 39 17500
# 1 loop, best of 1: 28.7 s per loop
# p++ three engines 39 18500
# 1 loop, best of 1: 1min 26s per loop
# p++ three engines 39 19500
# 1 loop, best of 1: 43.7 s per loop
# p++ two engines 39 500
# 1 loop, best of 1: 2.47 s per loop
# p++ two engines 39 1500
# 1 loop, best of 1: 3.02 s per loop
# p++ two engines 39 2500
# 1 loop, best of 1: 2.8 s per loop
# p++ two engines 39 3500
# 1 loop, best of 1: 6.76 s per loop
# p++ two engines 39 4500
# 1 loop, best of 1: 4.16 s per loop
# p++ two engines 39 5500
# 1 loop, best of 1: 3.77 s per loop
# p++ two engines 39 6500
# 1 loop, best of 1: 9.26 s per loop
# p++ two engines 39 7500
# 1 loop, best of 1: 22.5 s per loop
# p++ two engines 39 8500
# 1 loop, best of 1: 6.54 s per loop
# p++ two engines 39 9500
# 1 loop, best of 1: 12.4 s per loop
# p++ two engines 39 10500
# 1 loop, best of 1: 19.4 s per loop
# p++ two engines 39 11500
# 1 loop, best of 1: 31.4 s per loop
# p++ two engines 39 12500
# 1 loop, best of 1: 7.17 s per loop
# p++ two engines 39 13500
# 1 loop, best of 1: 40.3 s per loop
# p++ two engines 39 14500
# 1 loop, best of 1: 10.9 s per loop
# p++ two engines 39 15500
# 1 loop, best of 1: 6.72 s per loop
# p++ two engines 39 16500
# 1 loop, best of 1: 30.2 s per loop
# p++ two engines 39 17500
# 1 loop, best of 1: 30.4 s per loop
# p++ two engines 39 18500
# 1 loop, best of 1: 1min 28s per loop
# p++ two engines 39 19500
# 1 loop, best of 1: 45.5 s per loop
# s++ 40 500
# 1 loop, best of 1: 659 ms per loop
# s++ 40 1500
# 1 loop, best of 1: 1.86 s per loop
# s++ 40 2500
# 1 loop, best of 1: 4.97 s per loop
# s++ 40 3500
# 1 loop, best of 1: 3.96 s per loop
# s++ 40 4500
# 1 loop, best of 1: 6.67 s per loop
# s++ 40 5500
# 1 loop, best of 1: 22.4 s per loop
# s++ 40 6500
# 1 loop, best of 1: 27.9 s per loop
# s++ 40 7500
# 1 loop, best of 1: 15.3 s per loop
# s++ 40 8500
# 1 loop, best of 1: 21.4 s per loop
# s++ 40 9500
# 1 loop, best of 1: 14.7 s per loop
# s++ 40 10500
# 1 loop, best of 1: 19.4 s per loop
# s++ 40 11500
# 1 loop, best of 1: 13.5 s per loop
# s++ 40 12500
# 1 loop, best of 1: 55.4 s per loop
# s++ 40 13500
# 1 loop, best of 1: 7.42 s per loop
# s++ 40 14500
# 1 loop, best of 1: 7.2 s per loop
# s++ 40 15500
# 1 loop, best of 1: 10.1 s per loop
# s++ 40 16500
# 1 loop, best of 1: 22.9 s per loop
# s++ 40 17500
# 1 loop, best of 1: 22.1 s per loop
# s++ 40 18500
# 1 loop, best of 1: 1min 56s per loop
# s++ 40 19500
# 1 loop, best of 1: 41.9 s per loop
# p++ four engines 40 500
# 1 loop, best of 1: 1.46 s per loop
# p++ four engines 40 1500
# 1 loop, best of 1: 2.76 s per loop
# p++ four engines 40 2500
# 1 loop, best of 1: 6.46 s per loop
# p++ four engines 40 3500
# 1 loop, best of 1: 4.53 s per loop
# p++ four engines 40 4500
# 1 loop, best of 1: 5.93 s per loop
# p++ four engines 40 5500
# 1 loop, best of 1: 21.5 s per loop
# p++ four engines 40 6500
# 1 loop, best of 1: 25.3 s per loop
# p++ four engines 40 7500
# 1 loop, best of 1: 14.9 s per loop
# p++ four engines 40 8500
# 1 loop, best of 1: 19.5 s per loop
# p++ four engines 40 9500
# 1 loop, best of 1: 13.6 s per loop
# p++ four engines 40 10500
# 1 loop, best of 1: 17.2 s per loop
# p++ four engines 40 11500
# 1 loop, best of 1: 12.2 s per loop
# p++ four engines 40 12500
# 1 loop, best of 1: 47.6 s per loop
# p++ four engines 40 13500
# 1 loop, best of 1: 7.11 s per loop
# p++ four engines 40 14500
# 1 loop, best of 1: 7 s per loop
# p++ four engines 40 15500
# 1 loop, best of 1: 8.98 s per loop
# p++ four engines 40 16500
# 1 loop, best of 1: 20.1 s per loop
# p++ four engines 40 17500
# 1 loop, best of 1: 18.9 s per loop
# p++ four engines 40 18500
# 1 loop, best of 1: 1min 36s per loop
# p++ four engines 40 19500
# 1 loop, best of 1: 35.1 s per loop
# p++ three engines 40 500
# 1 loop, best of 1: 1.86 s per loop
# p++ three engines 40 1500
# 1 loop, best of 1: 3.05 s per loop
# p++ three engines 40 2500
# 1 loop, best of 1: 7.2 s per loop
# p++ three engines 40 3500
# 1 loop, best of 1: 4.55 s per loop
# p++ three engines 40 4500
# 1 loop, best of 1: 6.64 s per loop
# p++ three engines 40 5500
# 1 loop, best of 1: 21.8 s per loop
# p++ three engines 40 6500
# 1 loop, best of 1: 26 s per loop
# p++ three engines 40 7500
# 1 loop, best of 1: 13.9 s per loop
# p++ three engines 40 8500
# 1 loop, best of 1: 20.4 s per loop
# p++ three engines 40 9500
# 1 loop, best of 1: 13.2 s per loop
# p++ three engines 40 10500
# 1 loop, best of 1: 17.4 s per loop
# p++ three engines 40 11500
# 1 loop, best of 1: 11.3 s per loop
# p++ three engines 40 12500
# 1 loop, best of 1: 47.3 s per loop
# p++ three engines 40 13500
# 1 loop, best of 1: 7.53 s per loop
# p++ three engines 40 14500
# 1 loop, best of 1: 5.99 s per loop
# p++ three engines 40 15500
# 1 loop, best of 1: 9.57 s per loop
# p++ three engines 40 16500
# 1 loop, best of 1: 18.7 s per loop
# p++ three engines 40 17500
# 1 loop, best of 1: 18.2 s per loop
# p++ three engines 40 18500
# 1 loop, best of 1: 1min 33s per loop
# p++ three engines 40 19500
# 1 loop, best of 1: 34.1 s per loop
# p++ two engines 40 500
# 1 loop, best of 1: 2.41 s per loop
# p++ two engines 40 1500
# 1 loop, best of 1: 3.52 s per loop
# p++ two engines 40 2500
# 1 loop, best of 1: 8 s per loop
# p++ two engines 40 3500
# 1 loop, best of 1: 4.93 s per loop
# p++ two engines 40 4500
# 1 loop, best of 1: 6.9 s per loop
# p++ two engines 40 5500
# 1 loop, best of 1: 23.6 s per loop
# p++ two engines 40 6500
# 1 loop, best of 1: 27.5 s per loop
# p++ two engines 40 7500
# 1 loop, best of 1: 15 s per loop
# p++ two engines 40 8500
# 1 loop, best of 1: 20.3 s per loop
# p++ two engines 40 9500
# 1 loop, best of 1: 13.8 s per loop
# p++ two engines 40 10500
# 1 loop, best of 1: 17.6 s per loop
# p++ two engines 40 11500
# 1 loop, best of 1: 12.9 s per loop
# p++ two engines 40 12500
# 1 loop, best of 1: 48 s per loop
# p++ two engines 40 13500
# 1 loop, best of 1: 6.83 s per loop
# p++ two engines 40 14500
# 1 loop, best of 1: 6.94 s per loop
# p++ two engines 40 15500
# 1 loop, best of 1: 9.2 s per loop
# p++ two engines 40 16500
# 1 loop, best of 1: 19.2 s per loop
# p++ two engines 40 17500
# 1 loop, best of 1: 18.4 s per loop
# p++ two engines 40 18500
# 1 loop, best of 1: 1min 35s per loop
# p++ two engines 40 19500
# 1 loop, best of 1: 35.2 s per loop

# %%
###############################################################
#Speed experiment: K-means++, serial vs parallel, different ks#
###############################################################

from matplotlib.offsetbox import AnchoredText
dataset_size = np.arange(500,30000,1000)

#Average over many random datasets:
rloops = 250

#######
# k=2 #
#######
rk = 2

for u in range(1,rloops+1):
    XX = create_data(dataset_size, rk)
    lds = len(dataset_size)

    #RECORD TIMINGS
    ts2 = np.zeros([lds,3],)
    ts2[:,0]=dataset_size

    #serial k means plus plus
    for i in range(0,lds):
        print("s++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o sk_means(XX[i], rk, seeding="k++", ReturnPlot = False)
        ts2[i,1] = z.best

    #parallel k means plus plus
    for i in range(0,lds):
        print("p++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, e_all, seeding="k++", ReturnPlot = False)
        ts2[i,2] = z.best
        
    if u == 1:
        tst2 = ts2
    else:
        tst2 = np.dstack((tst2,ts2))

#calculate mean values
ts2 = numpy.mean(tst2, axis=2)

#######
# k=3 #
#######
rk = 3

for u in range(1,rloops+1):
    XX = create_data(dataset_size, rk)
    lds = len(dataset_size)

    #RECORD TIMINGS
    ts3 = np.zeros([lds,3],)
    ts3[:,0]=dataset_size

    #serial k means plus plus
    for i in range(0,lds):
        print("s++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o sk_means(XX[i], rk, seeding="k++", ReturnPlot = False)
        ts3[i,1] = z.best

    #parallel k means plus plus
    for i in range(0,lds):
        print("p++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, e_all, seeding="k++", ReturnPlot = False)
        ts3[i,2] = z.best
        
    if u == 1:
        tst3 = ts3
    else:
        tst3 = np.dstack((tst3,ts3))

#calculate mean values
ts3 = numpy.mean(tst3, axis=2)

#######
# k=4 #
#######
rk = 4

for u in range(1,rloops+1):
    XX = create_data(dataset_size, rk)
    lds = len(dataset_size)

    #RECORD TIMINGS
    ts4 = np.zeros([lds,3],)
    ts4[:,0]=dataset_size

    #serial k means plus plus
    for i in range(0,lds):
        print("s++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o sk_means(XX[i], rk, seeding="k++", ReturnPlot = False)
        ts4[i,1] = z.best

    #parallel k means plus plus
    for i in range(0,lds):
        print("p++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, e_all, seeding="k++", ReturnPlot = False)
        ts4[i,2] = z.best
        
    if u == 1:
        tst4 = ts4
    else:
        tst4 = np.dstack((tst4,ts4))

#calculate mean values
ts4 = numpy.mean(tst4, axis=2)

################
#     plot     #
################
f_skmeans_vs_pkmeans, (ax1, ax2, ax3) = plt.subplots(3, figsize=(8,11), sharex=True, sharey=True)

#ax1 for plot where k=2
ax1.plot(ts2[:,0], ts2[:,1], 'r--', label="Serial execution K-means++")
ax1.plot(ts2[:,0], ts2[:,2], 'b--', label="Parallel execution K-means++")

#ax2 for plot where k=3
ax2.plot(ts3[:,0], ts3[:,1], 'r--', label="Serial execution K-means++")
ax2.plot(ts3[:,0], ts3[:,2], 'b--', label="Parallel execution K-means++")

#ax3 for plot where k=4
ax3.plot(ts4[:,0], ts4[:,1], 'r--', label="Serial execution K-means++")
ax3.plot(ts4[:,0], ts4[:,2], 'b--', label="Parallel execution K-means++")

# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but bottom plot.
f_skmeans_vs_pkmeans.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f_skmeans_vs_pkmeans.axes[:-1]], visible=False)

#add labels etc.
ax3.set_xlabel("data set size")
ax2.set_ylabel("execution time (s)")

ax1.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)

ax1.add_artist(AnchoredText("k=2", loc=2))
ax2.add_artist(AnchoredText("k=3", loc=2))
ax3.add_artist(AnchoredText("k=4", loc=2))

f_skmeans_vs_pkmeans.savefig("f_skmeans_vs_pkmeans.eps", format="eps", bbox_inches="tight")
f_skmeans_vs_pkmeans.savefig("f_skmeans_vs_pkmeans.jpg", format="jpg", bbox_inches="tight")

# %%
###############################################################
#Speed experiment: GMM++, serial vs parallel, different ks#
###############################################################

from matplotlib.offsetbox import AnchoredText
#dataset_size = np.arange(500,30000,1000)
dataset_size = np.arange(500,650,100)

#Average over many random datasets:
rloops = 2 #100
#GMM-threshold for convergence
thresh = 0.0001

#######
# k=2 #
#######
rk = 2

for u in range(1,rloops+1):
    XX = create_data(dataset_size, rk)
    lds = len(dataset_size)

    #RECORD TIMINGS
    ts2 = np.zeros([lds,3],)
    ts2[:,0]=dataset_size

    #serial GMM, initliazed through kmeans++
    for i in range(0,lds):
        print("sGMM",u, len(XX[i]))
        z = %timeit -n1 -r1 -o sGMM(X=XX[i], k=rk, threshold = thresh, seeding="kmeans++", ReturnPlots=False)
        ts2[i,1] = z.best

                
    #parallel GMM, initialized through kmeans++
    for i in range(0,lds):
        print("pGMM",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pGMM(X=XX[i], k=rk, threshold = thresh, seeding="kmeans++", view = e_all, ReturnPlots=False)
        ts2[i,2] = z.best
        
    if u == 1:
        tst2 = ts2
    else:
        tst2 = np.dstack((tst2,ts2))

#calculate mean values
ts2 = numpy.mean(tst2, axis=2)

#######
# k=3 #
#######
rk = 3

for u in range(1,rloops+1):
    XX = create_data(dataset_size, rk)
    lds = len(dataset_size)

    #RECORD TIMINGS
    ts3 = np.zeros([lds,3],)
    ts3[:,0]=dataset_size

    #serial GMM, initliazed through kmeans++
    for i in range(0,lds):
        print("sGMM",u, len(XX[i]))
        z = %timeit -n1 -r1 -o sGMM(X=XX[i], k=rk, threshold = thresh, seeding="kmeans++", ReturnPlots=False)
        ts3[i,1] = z.best

    #parallel GMM, initialized through kmeans++
    for i in range(0,lds):
        print("pGMM",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pGMM(X=XX[i], k=rk, threshold = thresh, seeding="kmeans++", view = e_all, ReturnPlots=False)
        ts3[i,2] = z.best
        
    if u == 1:
        tst3 = ts3
    else:
        tst3 = np.dstack((tst3,ts3))

#calculate mean values
ts3 = numpy.mean(tst3, axis=2)

#######
# k=4 #
#######
rk = 4

for u in range(1,rloops+1):
    XX = create_data(dataset_size, rk)
    lds = len(dataset_size)

    #RECORD TIMINGS
    ts4 = np.zeros([lds,3],)
    ts4[:,0]=dataset_size

    #serial GMM, initliazed through kmeans++
    for i in range(0,lds):
        print("sGMM",u, len(XX[i]))
        z = %timeit -n1 -r1 -o sGMM(X=XX[i], k=rk, threshold = thresh, seeding="kmeans++", ReturnPlots=False)
        ts4[i,1] = z.best

    #parallel GMM, initialized through kmeans++
    for i in range(0,lds):
        print("pGMM",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pGMM(X=XX[i], k=rk, threshold = thresh, seeding="kmeans++", view = e_all, ReturnPlots=False)

        ts4[i,2] = z.best
        
    if u == 1:
        tst4 = ts4
    else:
        tst4 = np.dstack((tst4,ts4))

#calculate mean values
ts4 = numpy.mean(tst4, axis=2)

################
#     plot     #
################
f_sGMM_vs_pGMM, (ax1, ax2, ax3) = plt.subplots(3, figsize=(8,11), sharex=True, sharey=True)

#ax1 for plot where k=2
ax1.plot(ts2[:,0], ts2[:,1], color='orange', linestyle='--', label="Serial execution GMM")
ax1.plot(ts2[:,0], ts2[:,2], 'm--', label="Parallel execution GMM")

#ax2 for plot where k=3
ax2.plot(ts3[:,0], ts3[:,1], color='orange', linestyle='--', label="Serial execution GMM")
ax2.plot(ts3[:,0], ts3[:,2], 'm--', label="Parallel execution GMM")

#ax3 for plot where k=4
ax3.plot(ts4[:,0], ts4[:,1], color='orange', linestyle='--', label="Serial execution GMM")
ax3.plot(ts4[:,0], ts4[:,2], 'm--', label="Parallel execution GMM")

# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but bottom plot.
f_sGMM_vs_pGMM.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f_sGMM_vs_pGMM.axes[:-1]], visible=False)

#add labels etc.
ax3.set_xlabel("data set size")
ax2.set_ylabel("execution time (s)")

ax1.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)

ax1.add_artist(AnchoredText("k=2", loc=2))
ax2.add_artist(AnchoredText("k=3", loc=2))
ax3.add_artist(AnchoredText("k=4", loc=2))

f_sGMM_vs_pGMM.savefig("f_sGMM_vs_pGMM.eps", format="eps", bbox_inches="tight")
f_sGMM_vs_pGMM.savefig("f_sGMM_vs_pGMM.jpg", format="jpg", bbox_inches="tight")
# Out:
# sGMM 1 500
# 1 loop, best of 1: 4.17 s per loop
# sGMM 1 600
# 1 loop, best of 1: 5.35 s per loop
# pGMM 1 500
# 1 loop, best of 1: 3.22 s per loop
# pGMM 1 600
# 1 loop, best of 1: 4.32 s per loop
# sGMM 2 500
# 1 loop, best of 1: 2.14 s per loop
# sGMM 2 600
# 1 loop, best of 1: 2.61 s per loop
# pGMM 2 500
# got unknown result: 1aec73e8-e5c7f577f2e45990ce6a1633
# 1 loop, best of 1: 3.34 s per loop
# pGMM 2 600
# got unknown result: b90463ba-76255f12ba588963b5d51161
# got unknown result: 1612ab2f-af9144f4b0bf81eacc0043a7
# 1 loop, best of 1: 4.24 s per loop
# sGMM 1 500
# 1 loop, best of 1: 2.93 s per loop
# sGMM 1 600
# 1 loop, best of 1: 3.45 s per loop
# pGMM 1 500
# 1 loop, best of 1: 3.44 s per loop
# pGMM 1 600
# got unknown result: 526d03e3-315875add31ba99f01804d90
# 1 loop, best of 1: 4.75 s per loop
# sGMM 2 500
# got unknown result: 43413e4f-fc88bf47f44902fd1d21bc7c
# 1 loop, best of 1: 5.73 s per loop
# sGMM 2 600
# 1 loop, best of 1: 20.4 s per loop
# pGMM 2 500
# 1 loop, best of 1: 4.27 s per loop
# pGMM 2 600
# got unknown result: 78bedbed-9af32bde0eca1cf3418ad16d
# got unknown result: dea95e32-822639d4f6474e350381c9b7
# 1 loop, best of 1: 23.6 s per loop
# sGMM 1 500
# 1 loop, best of 1: 3.82 s per loop
# sGMM 1 600
# 1 loop, best of 1: 11.2 s per loop
# pGMM 1 500
# 1 loop, best of 1: 5.05 s per loop
# pGMM 1 600
# got unknown result: 6249923b-be07451cfcb7bb479f144a38
# 1 loop, best of 1: 11.1 s per loop
# sGMM 2 500
# 1 loop, best of 1: 7.16 s per loop
# sGMM 2 600
# 1 loop, best of 1: 10.2 s per loop
# pGMM 2 500
# 1 loop, best of 1: 7.94 s per loop
# pGMM 2 600
# got unknown result: 864f8d4c-f4d67c7897393a32c6352a7f
# 1 loop, best of 1: 9.8 s per loop
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-5835282c8d63> in <module>()
#     133 # all but bottom plot.
#     134 f_sGMM_vs_pGMM.subplots_adjust(hspace=0)
# --> 135 plt.setp([a.get_xticklabels() for a in f_skmeans_vs_pkmeans.axes[:-1]], visible=False)
#     136
#     137 #add labels etc.
#
# NameError: name 'f_skmeans_vs_pkmeans' is not defined

# %%
#compare k-means to GMM on anisotropic data
#create sammple data

n_samples = 1500
X, y = make_blobs(n_samples=n_samples, centers=3, random_state = 170)

# Anisotropicly distributed data
transformation = [[ 0.60834549, -0.63667341], [-0.40887718, 0.85253229]]
X = np.dot(X, transformation)

#add grid
#V = np.zeros([130,2],)
#V[:,0] = list(np.linspace(-6,3,10)) * 13
#V[:,1] = list(np.linspace(-4,8,13)) * 10

#X = np.vstack((X,V))

#k-means
a = pk_means(X, k=3, view=e_all, seeding="k++", ReturnPlot = True)

#GMM
b, c = pGMM(X, k=3, threshold = 0.001, seeding="kmeans++", view = e_all, ReturnPlots=True)
# Out:
# got unknown result: b4175d95-326a1c60e1cead29faed582a
# got unknown result: 13766552-0ed66e8fc359cffa253b9df2
# got unknown result: 4c1ea002-a4462b4b5a4503cc25a5020d

# %%
a.savefig("f_aniso_kmeans.eps", format="eps", bbox_inches="tight")
a.savefig("f_aniso_kmeans.jpg", format="jpg", bbox_inches="tight")

c.savefig("f_likelihood.eps", format="eps", bbox_inches="tight")
c.savefig("f_likelihood.jpg", format="jpg", bbox_inches="tight")

b.savefig("f_aniso_GMM.eps", format="eps", bbox_inches="tight")
b.savefig("f_aniso_GMM.jpg", format="jpg", bbox_inches="tight")

# %%
###############################################################
#Speed experiment: K-means++, serial vs parallel, different ks#
###############################################################

from matplotlib.offsetbox import AnchoredText
dataset_size = np.arange(500,30000,1000)

#Average over many random datasets:
rloops = 250

#######
# k=2 #
#######
rk = 2

for u in range(1,rloops+1):
    XX = create_data(dataset_size, rk)
    lds = len(dataset_size)

    #RECORD TIMINGS
    ts2 = np.zeros([lds,3],)
    ts2[:,0]=dataset_size

    #serial k means plus plus
    for i in range(0,lds):
        print("s++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o sk_means(XX[i], rk, seeding="k++",\
                                        ReturnPlot = False)
        ts2[i,1] = z.best

    #parallel k means plus plus
    for i in range(0,lds):
        print("p++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, e_all, seeding="k++",\
                                        ReturnPlot = False)
        ts2[i,2] = z.best
        
    if u == 1:
        tst2 = ts2
    else:
        tst2 = np.dstack((tst2,ts2))

#calculate mean values
ts2 = numpy.mean(tst2, axis=2)

#######
# k=3 #
#######
rk = 3

for u in range(1,rloops+1):
    XX = create_data(dataset_size, rk)
    lds = len(dataset_size)

    #RECORD TIMINGS
    ts3 = np.zeros([lds,3],)
    ts3[:,0]=dataset_size

    #serial k means plus plus
    for i in range(0,lds):
        print("s++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o sk_means(XX[i], rk, seeding="k++",\
                                        ReturnPlot = False)
        ts3[i,1] = z.best

    #parallel k means plus plus
    for i in range(0,lds):
        print("p++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, e_all, seeding="k++",\
                                        ReturnPlot = False)
        ts3[i,2] = z.best
        
    if u == 1:
        tst3 = ts3
    else:
        tst3 = np.dstack((tst3,ts3))

#calculate mean values
ts3 = numpy.mean(tst3, axis=2)

#######
# k=4 #
#######
rk = 4

for u in range(1,rloops+1):
    XX = create_data(dataset_size, rk)
    lds = len(dataset_size)

    #RECORD TIMINGS
    ts4 = np.zeros([lds,3],)
    ts4[:,0]=dataset_size

    #serial k means plus plus
    for i in range(0,lds):
        print("s++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o sk_means(XX[i], rk, seeding="k++",\
                                        ReturnPlot = False)
        ts4[i,1] = z.best

    #parallel k means plus plus
    for i in range(0,lds):
        print("p++",u, len(XX[i]))
        z = %timeit -n1 -r1 -o pk_means(XX[i], rk, e_all, seeding="k++",\
                                        ReturnPlot = False)
        ts4[i,2] = z.best
        
    if u == 1:
        tst4 = ts4
    else:
        tst4 = np.dstack((tst4,ts4))

#calculate mean values
ts4 = numpy.mean(tst4, axis=2)

################
#     plot     #
################
f_skmeans_vs_pkmeans, (ax1, ax2, ax3) = plt.subplots(3, figsize=(8,11),\
                                                sharex=True, sharey=True)

#ax1 for plot where k=2
ax1.plot(ts2[:,0], ts2[:,1], 'r--', label="Serial execution K-means++")
ax1.plot(ts2[:,0], ts2[:,2], 'b--', label="Parallel execution K-means++")

#ax2 for plot where k=3
ax2.plot(ts3[:,0], ts3[:,1], 'r--', label="Serial execution K-means++")
ax2.plot(ts3[:,0], ts3[:,2], 'b--', label="Parallel execution K-means++")

#ax3 for plot where k=4
ax3.plot(ts4[:,0], ts4[:,1], 'r--', label="Serial execution K-means++")
ax3.plot(ts4[:,0], ts4[:,2], 'b--', label="Parallel execution K-means++")

# Fine-tune figure; make subplots close to each other and hide x ticks for
# all but bottom plot.
f_skmeans_vs_pkmeans.subplots_adjust(hspace=0)
plt.setp([a.get_xticklabels() for a in f_skmeans_vs_pkmeans.axes[:-1]],\
                                                 visible=False)

#add labels etc.
ax3.set_xlabel("data set size")
ax2.set_ylabel("execution time (s)")

ax1.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)

ax1.add_artist(AnchoredText("k=2", loc=2))
ax2.add_artist(AnchoredText("k=3", loc=2))
ax3.add_artist(AnchoredText("k=4", loc=2))

f_skmeans_vs_pkmeans.savefig("f_skmeans_vs_pkmeans.eps", format="eps",\
                             bbox_inches="tight")
f_skmeans_vs_pkmeans.savefig("f_skmeans_vs_pkmeans.jpg", format="jpg",\
                             bbox_inches="tight")
